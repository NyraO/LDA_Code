# %%
import gensim
import pandas as pd
import numpy as np
from gensim.models import LsiModel
import matplotlib.pyplot as plt
from gensim.models import CoherenceModel

# %%
df=pd.read_csv('processedDEV.csv')
df=df.drop(['Unnamed: 0'], axis = 1)
my_list=df.to_numpy().tolist()
#my_list

# %%
#my_doc=pd.read_csv('C:/Users/Kois/unLemmatizedCorpus.csv') #unLemmatized tokens
my_root=pd.read_csv('C:/Users/Kois/lemmatizedCorpus.csv') #Lemmatized tokens
my_root=my_root.drop(['Unnamed: 0.1'], axis = 1)
my_root=my_root.drop(['Unnamed: 0'], axis = 1)
my_root=my_root.to_numpy().tolist()
len(my_root)
# Out:
# 7050

# %%
new_list=[]
temp_list=[]
for x in my_root:
    for item in x:
        if str(item) != 'nan':
            temp_list.append(item)
    new_list.append(temp_list)
    temp_list=[]
#new_list

# %%
stop_words=['እኔ', 'የእኔ', 'እኔራሤ', 'እኛ', 'የእኛ', 'እኛራሣችን', 'አንቺ', 'ነህ', 'አላችሁ', 'እርሥዎ', 'ትፈልጋለህ', 'ያንተ', 'ራሥህን', 'እራሣችሁ', 'እሡ', 'የእሡ',
 'ራሡ', 'እሷ', 'እሷናት', 'የእሷ', 'እራሷ', 'ነው', 'እነሡ', 'እነሡን', 'የእነሡ', 'ራሣቸው', 'ምንድን', 'የትኛው', 'ማን', 'ይህ', 'የሚልነው', 'ያ', 'እነዚህ', 'እነዚያ', 'ነኝ', 'ናቸው', 'ነበር', 'ነበሩ', 'ሁን', 'ቆይቷል', 'መሆን',
 'አላቸው', 'አለው', 'ነበረው', 'ያለው', 'መሥራት', 'ያደርጋል', 'አደረገ', 'ማድረግ', 'ሀ', 'አንድ', 'የ', 'እና', 'ከሆነ', 'ወይም', 'ምክንያቱም',
 'እንደ', 'እሥከ', 'እያለ', 'በ', 'ለ', 'ጋር', 'ሥለ', 'ላይ', 'መካከል', 'ወደ', 'በኩል', 'ወቅት', 'ከዚህበፊት', 'በኋላ', 'ከላይ', 'ከታች', 'ከ', 'ወደላይ', 'ታች', 'ውሥጥ', 'ውጭ', 'በላይ',
 'እንደገና', 'ተጨማሪ', 'ከዚያ', 'አንድጊዜ', 'እዚህ', 'እዚያ', 'መቼ', 'የት', 'ለምን', 'እንዴት', 'ሁሉም', 'ማንኛውም', 'ሁለቱም', 'እያንዳንዳቸው', 'ጥቂቶች', 'በጣም', 'ሌላ', 'አንዳንድ',
 'እንደዚህ', 'ብቻ', 'የራሡ', 'ተመሣሣይ', 'ሥለዚህ', 'ይልቅ', 'እንዲሁ', 'ት', 'ይችላል', 'ይገባል', 'ይገባኛል', 'አሁን', 'መ', 'ም', 'ኦ', 'ዳግም',
 'መሆን', 'ሁለ', 'ሁለም', 'ህዝብ', 'ሀሙሥ', 'ለመሆኑ', 'ለምንድን', 'ሌሎች', 'መጽሀፍ', 'ማክሠኞ', 'ምን', 'ሠኞ', 'ሠው', 'ሢሆን', 'ሥንት', 'ረቡእ',
 'ቅዳሜ', 'በዚህ', 'ብላ', 'ነገር', 'አለ', 'አርብ', 'አንተ', 'አንዳንድ', 'ኢትዮጵያ', 'እሁድ', 'እናንተ', 'እንኳን', 'እግር', 'ከመሆን', 'ወይንም', 'ዋና', 'ዘንድ', 'የሚከተለው', 'ያኔ', 'ይኼው', 'ገጽ', 'እነርሡ',
 'ን', 'ና', 'ዎች', 'ይጠበቃል', 'ብለዋል', 'ሆ', 'ሁሉ', 'አንቀጽ', 'እንደሆነ', 'በማይበልጥ', 'መሠረት', 'ሁኔታ', 'ይሆናል', 'ሆኖ', 'ከአንድ', 'በማናቸውም',
 'ወር', 'ከአምሥት', 'በሆነ', 'ከዚህ', 'የሆነ', 'ሀያ', 'ሆነ', 'በኊላ', 'በአንድ', 'የሆኑ', 'ከአሥራ', 'የሆነውን', 'መሆኑ', 'ሌላውን', 'ከሠባት', 'ለሌላ',
 'አለበት', 'ሢል', 'ይሆናሉ', 'በሙሉ', 'አሥራ', 'ቢሆንም', 'አንዱ', 'የሌላውን', 'ከሁለት', 'የሆኑትን', 'በሆኑ', 'ጀምሮ', 'በመሆን', 'ባለ', 'ይህንን', 'እንዲቆይ', 'ሌላው', 'የሚሆነው', 'በአንዱ', 'ሢባል', 'ሣለ', 'የሆነው', 'መሆናቸው', 'በዋና', 'በማቀድ', 'ጊዜና', 'ለዚህ', 'ሦሥተኛ', 'የነገሩ', 'ሥድሥት', 'በሆነው', 'ይሁን', 'ከዚሁ', 'በእነዚህ', 'ከማናቸውም', 'ከነበረው',
 'በአንዳንድ', 'በእያንዳንዱ', 'ጊዜም', 'አሥከ', 'የሌሎች', 'የሚሆኑት', 'ከሆነው', 'የነበረውን', 'ያሉ', 'ከሌሎች', 'አንዲት', 'ለሌሎች', 'ለሆነው', 'ሠኣት', 'ብሎ', 'ከሠላሣ',
 'የሚሆኑ', 'ላይም', 'የሆናል', 'ከነዚህ', 'ያህል', 'ከሆነና', 'ለሆኑት', 'እነዚሁ', 'እንደሆኑ', 'ሥለማናቸውም', 'ሥለዚሁ', 'ከአንዳንድ',
 'በእነዚሁ', 'በአምሥት', 'የሆኑበታል', 'ለነዚህ', 'ለማንኛውም', 'አንደኛ', 'ይኸኛው', 'ከርሡ', 'መሆኑን', 'ለዚያው', 'ለዚሁ', 'ለእነርሡም', 'እዚሁ', 'ሀ', 'ረ', 'ሸ', 'አምሥት',
 'ከሦሥት', 'በተለይም', 'በሌላ', 'ሺህ', 'ማናቸውንም', 'ከአሥር', 'የማይበልጥ', 'እንዲሁም', 'ይህን', 'የዚህ', 'ማናቸውም', 'ከሥድሥት', 'መቶ', 'ያለ', 'አንድን',
 'ያላቸውን', 'ሊሆን', 'ሦሥት', 'ካልሆነ', 'ቢያንሥ', 'ቢሆን', 'እነዚህን', 'አንዱን', 'ሁለት', 'ወይዘሮ', 'ተብሎ', 'ሣይሆን', 'እንደሆነና', 'ከብር', 'ሆኖም', 'የነበሩ',
 'የሌላ', 'ያላቸው', 'ይህንኑ', 'ሆነው', 'በሥተቀር', 'ሥም', 'እንደገና', 'የማያንሥ', 'እጅግ', 'እንዲሆን', 'እንኳ', 'ከሀያ', 'ከሀምሣ', 'ይኸው', 'ለአንድ', 'የሚችለውን',
 'በሚገባ', 'ይህም', 'እንዲሆኑ', 'ከሌላ', 'ለሆነ', 'በሌሎች', 'አንደሆነ', 'እንዲህ', 'በነዚሁ', 'በእንደዚህ', 'ሥምንት', 'ሢሆንና', 'ምንጊዜም', 'ለማናቸውም', 'የአንድ', 'እነዚህኑ', 'ሢሆኑ', 'በሁለቱም',
 'እንደነዚህ', 'የሆኑት', 'የማናቸውም', 'ይህንንም', 'የአንድን', 'በሙሉም', 'በነዚህ', 'የዚሁ', 'ለእያንዳንዱ', 'ሥለሆነ', 'መሆናቸውን', 'ማንኛውንም', 'ሁለቱ', 'እንጂ',
 'ከሥምንት', 'ሁለቱንም', 'በሁለት', 'በእሥር', 'በሚል', 'ቁጥር', 'ባሉ', 'ከመቶ', 'እነዚህም', 'ሢኖር', 'ሠላሣ', 'ለሆኑ', 'ሠባት', 'እነደሆነ', 'ይህችው', 'ከእነዚህ',
 'ከእነዚሁ', 'የአንቀጹ', 'ወይ', 'የሆነችን']

# %%
def stopWordRemoval(tokens):
    token_new=[]
    for x in tokens:
        if x not in stop_words:
            token_new.append(x)
    return token_new

# %%
processed_docs=[]
for item in new_list:
    processed_docs.append(stopWordRemoval(item))
processed_docs
# Out:
# [['ልዩ', 'ተፈጥሮ', 'ገጽታ', 'ምስራቅ', 'አፍሪካ', 'ውሀ', 'ማማ', 'ጮቅ'],
#  ['ሀገር',
#   'ጥቅም',
#   'ተሰለፈ',
#   'ሰጠ',
#   'መላጣ',
#   'ነአ',
#   'የሻቢይን',
#   'ይሁንታ',
#   'ተገኘ',
#   'ሀገር',
#   'ባህር',
#   'ሰጠ',
#   'ታምራት',
#   'እውነታ',
#   'ውርእ',
#   'እርር',
#   'መጣ',
#   'ሚሊዮን',
#   'አበረ'],
#  ['ብጄ',
#   'አሳምነው_ጽጌ',
#   'ምክትል',
#   'ጠማ',
#   'ደመቀ',
#   'ሱዳን',
#   'ጉብኝት',
#   'አልበሽር',
#   'ተመስገን',
#   'ነገረ',
#   'ጥር',
#   'ጎረቤት',
#   'ከህወሀት',
#   'ግን',
#   'ቤተሰብ'],
#  ['"ትልልቅ',
#   'ነደደ',
#   'ፍጆታ',
#   'ተሽከርካሪ',
#   'አየር',
#   'ብክለት',
#   'አኳያ',
#   'ነዳጅ',
#   'ወጣ',
#   'ረገድ',
#   'ለየ',
#   'ኤክሳይዝ_ታክስ',
#   'ጣለ',
#   'ገባ',
#   'ሊትር',
#   'ኪሎ',
#   'ሜትር',
#   'ነዳ',
#   'ለየ',
#   'አተያይ',
#   'ኖረ',
#   'ጠይቀዋል"'],
#  ['እሺ', 'ወንድም', 'ተከለ', 'ማኛ', 'እኮ', 'ወዳታለሁ', 'ደሞ', 'ቀና', 'አሉ'],
#  ['ይቺ', 'አወቀ', 'ዶር_አብይ', 'ክርስቲያን', 'የሆነዋኧረ', 'ጀንፈሉ', 'እንጣጥ', 'እንጣጥ', 'ዋዋዋ'],
#  ['ፈለገ',
#   'መብት',
#   'ኖረ',
#   'መብት',
#   'ወሰነ',
#   'ግን',
#   'ኖረ',
#   'ሀገር',
#   'ህግ',
#   'ኖረ',
#   'ቻለ',
#   'መብት',
#   'እኩልነት',
#   'ተገኛኘ',
#   'ህግ'],
#  ['ንነቴ', 'ኢትዮጵያዊነቴ', 'መታ', 'አወቀ', 'ተከለ'],
#  ['ለቅዳሚታችሁ',
#   'ሰረረ',
#   'ምሉእነትና',
#   'እርካታ',
#   'ሰማ',
#   'የአሁንነት',
#   'ሀይል',
#   'መንፈሳዊ',
#   'እውቀት',
#   'ብርሀን',
#   'መራ',
#   'በኤክሀርት',
#   'ቶሌየተዘጋጀ'],
#  ['ኮንዶሚኒየም', 'መለሰ', 'መልስ', 'ባከነ'],
#  ['ስንታየሁም',
#   'ኤልያስ',
#   'ፓርላማ',
#   'ገባ',
#   'አነሰ',
#   'ደገመ',
#   'ያዘ',
#   'ፓርቲ',
#   'መሰረተ',
#   'ማነው',
#   'መቸም',
#   'እስክንድር',
#   'በየምክኒያቱ',
#   'ዱላ',
#   'አነሳ',
#   'ለም',
#   'መርህ',
#   'መራ',
#   'ጽኑ',
#   'ኖረ',
#   'አለቀ',
#   'አስቀመጠ'],
#  ['ለካ',
#   'ጭብል',
#   'ለበሰ',
#   'ፕሮፌሰር',
#   'ፎቶ',
#   'ለጥፈክ',
#   'ልም',
#   'ላከ',
#   'ባዳ',
#   'ነክ',
#   'ፈር',
#   'ትንሽ'],
#  ['ታህሳስ',
#   'ቀን',
#   'ሞጣ',
#   'ከተማ',
#   'አስተዳደር',
#   'በመስጅዶችና',
#   'ሱቅ',
#   'ደረሰ',
#   'እሳት',
#   'ቃጠሎ',
#   'አወገዘ',
#   'እስልምና',
#   'ሀይማኖት',
#   'ተከታይ',
#   'ባህር_ዳር',
#   'ሰላማዊ_ሰልፍ',
#   'አካሄደ',
#   'ተገኘ'],
#  ['አሜሪካ',
#   'ሱሌይማኒን',
#   'ገደለ',
#   'ቀይ',
#   'መስመር',
#   'አለፈ',
#   'ቀረረ',
#   'ዜጋ',
#   'ሀገር',
#   'ለቀቀ',
#   'ውጥእ',
#   'አዝዛለች',
#   'ጀለሶቿ',
#   'ደገመ',
#   'አሉ',
#   'ለመጠ',
#   'ጀመረ'],
#  ['ይሄው', 'አይደል', 'እውቀት', 'ጥግበሰሚ', 'ሰማ', 'ተናገረ', 'ታሪክ', 'አታነቢምደሞ', 'ራስ', 'ገመተ'],
#  ['ባከነ', 'ጊዜ', 'ኖረ', 'ዶለ', 'ስራ'],
#  ['ጎንደር', 'ዩኒቨርሲቲ', 'ተማሪዎችመምህራንና', 'አስተዳደር', 'ሰራተኛ', 'እርምጃ_ወሰደ'],
#  ['አማራ',
#   'ክልል',
#   'ፈጠረ',
#   'አወገዘ',
#   'ለም',
#   'ፖለቲከኛ',
#   'እስከሊስትሮ',
#   'ድረስ',
#   'ኦሮሞ',
#   'ክልል',
#   'ግን',
#   'ሰቀቀ',
#   'ሽብር',
#   'ፈጸመ',
#   'ለየ',
#   'የሚያልፎት',
#   'አወገዘ',
#   'ቀረ'],
#  ['ዛሬ',
#   'ጁመአ',
#   'ወሎ',
#   'ኮንቦልቻ',
#   'የተደረካ',
#   'ከባድ',
#   'መልክት',
#   'የቃውሞ',
#   'ሰልፍ',
#   'ብልጽግና',
#   'ፓርቲ',
#   'ብልጽግና',
#   'አየ'],
#  ['ትንሽ', 'ቈየ', 'ዶርብርሀኑና', 'በዶር', 'አብይ', 'ልዩነት', 'ለም', 'ምፈራው'],
#  ['ቢቢሲ', 'ዘገበ', 'በላ', 'ተባለ', 'አንተዉ', 'ነገረ'],
#  ['አማራ',
#   'ክልል',
#   'ፈላ',
#   'ልክ',
#   'ገባ',
#   'ሙስሊም',
#   'ጠላ',
#   'ሙስሊም',
#   'ኖረ',
#   'ኦሮምያ',
#   'ግንኙነት',
#   'አትሰበው'],
#  ['እረ',
#   'ፈጠረ',
#   'እንቅጩን',
#   'ነገረ',
#   'እህህ',
#   'መታ',
#   'በቃ',
#   'አያት',
#   'ቀነተ',
#   'ፈታ',
#   'ግድብ',
#   'ከፈለ',
#   'ዋጋ',
#   'ሞተ',
#   'እንድታየወ',
#   'ድርግ'],
#  ['ባህል',
#   'ድርግ',
#   'ገለጸ',
#   'ገለጠ',
#   'ደበነ',
#   'ኢመደበኛ',
#   'ስርአታት',
#   'ስር',
#   'ሰደደ',
#   'ጐለተ',
#   'ሊይታዩ',
#   'ቻለ',
#   'የጎንዮሽ_ኢእኩልነት',
#   'አብላጫውን',
#   'ፖለቲካ',
#   'ንቅናቄ',
#   'ሂደት',
#   'ተቈጣ'],
#  ['ጥበበኛ', 'ፍቅር', 'ማረ', 'ቴዲ', 'አፈረ'],
#  ['አቢይ_አህመድ',
#   'መንግስት',
#   'ድርግ',
#   'እርካታ',
#   'በጎ',
#   'ተግባር',
#   'ዘረዘረ',
#   'ተቻለ',
#   'ግን',
#   'መንግስት',
#   'ጀመረ',
#   'ሀላፊነት',
#   'ዜጋ_ደህንነት',
#   'ጠበቀ',
#   'ረገድ'],
#  ['ጽድቅ', 'ኩነኔ', 'ኖረ', 'ኖረ', 'ክፋት', 'ደግነት', 'ተሻለ', 'ቀረረ', 'ፉት'],
#  ['መንግስት',
#   'ሆይ',
#   'ሀገሪቷን',
#   'ፈላ',
#   'መፈንጫ',
#   'ተወ',
#   'ሰላም',
#   'ፈለገ',
#   'ጉልበት',
#   'መረጠ',
#   'እቅፍ',
#   'አበባ',
#   'ደቃ',
#   'ጠንካራ',
#   'ክንድ',
#   'ተቀበለ',
#   'እግድ'],
#  ['በ"መጽሀፈ',
#   'ጨዋታ"',
#   'መሰናዶ',
#   'አየ',
#   'ተመቸ',
#   'ቃለ',
#   'መጠይቅ',
#   'የተካሄበት',
#   'ቦታ',
#   'ላይብረሪ',
#   'መሰለ',
#   'ተሰንደው',
#   'ደረደረ',
#   'ጋዜጣ',
#   'ሞላ',
#   'ምሳሌ',
#   'አዲስ',
#   'ዘመን',
#   'ሪፖርተር',
#   'ፎርቹን',
#   'አዲስ',
#   'አድማስ',
#   'ጋዜጣ',
#   'ተሰንደው',
#   'ተመለከተ'],
#  ['ድሮ',
#   'ዘመነ',
#   'ኮዳክ',
#   'ፎቶ',
#   'ቤት',
#   'ፍላሹ',
#   'ፏ',
#   'አይን',
#   'ጨፈነ',
#   'ውጥእ',
#   'የምንቸክለውን',
#   'እውስ',
#   'ግን',
#   'ኋላ',
#   'ቴዲ',
#   'ፊት',
#   'ዞረ',
#   'እኮ'],
#  ['ዠለጠ', 'ገገማ'],
#  ['ታቦተ',
#   'ህግ',
#   'እግዚአብሄር',
#   'በካህናታ',
#   'ህጽርት',
#   'ወበመንፈስቅዱስ',
#   'ክልልት',
#   'ንጉስኪ',
#   'ጽዮን',
#   'ኢይትመዋእ',
#   'ጸር',
#   'ወኢየሀድጋ',
#   'ሀገር',
#   'ካህን',
#   'ከበበ',
#   'ነፈሰ',
#   'ቅዱስ',
#   'ተከለ',
#   'እግዚአብሄር',
#   'ታቦተ',
#   'ህግ',
#   'ጽዮን',
#   'ንጉስ',
#   'ጠላት',
#   'ተሸነፈ',
#   'ሀገር',
#   'ተወ'],
#  ['አማ',
#   'ልሙጥ',
#   'ባንዴራን',
#   'ለቤተክርስትያኒቷ',
#   'አስረክባቹ',
#   'ተሻለ',
#   'መንገደ',
#   'ሰለማዊና',
#   'ረጋ',
#   'ክልል',
#   'ፈጠረ',
#   'ሰርታቹ',
#   'አየ',
#   'ተዛ',
#   'መጣ',
#   'ወራሪጠላት',
#   'አበረ',
#   'ንቆማለን'],
#  ['ብድር',
#   'ምድር',
#   'ተገቢ',
#   'ፊት',
#   'ተቃወመ',
#   'ነበረ',
#   'ነበረ',
#   'ታድያ',
#   'ጉልቻ',
#   'ቀየረ',
#   'ነዋ',
#   'ሀገሬ',
#   'ደግ',
#   'መጣ'],
#  ['ለውጥ', 'አለመ', 'ኦሮሚያ', 'ባለሀብት', 'ውይይት'],
#  ['ሀገር',
#   'ችግር',
#   'አወቀ',
#   'መፍትሄ',
#   'መጣ',
#   'ትክክል',
#   'ሀገር',
#   'ይቺ',
#   'ወጣት',
#   'እንጀራ',
#   'ገገረ',
#   'ፈለገ',
#   'አብሲት',
#   'ለየ',
#   'ቀለለ',
#   'ዘዴ',
#   'ተዘጋጀ',
#   'እናት',
#   'ውለታ',
#   'ዋለ',
#   'ሰይፍ',
#   'በኢቢኤስ'],
#  ['አያውቅምእና', 'ያውቃልአይባልም'],
#  ['ስውር', 'ጭምር', 'ሂሉን', 'እሺ', 'ተቻለ', 'ሚገርመኝ'],
#  ['ሀይማኖት', 'መሪ', 'ክርስትና', 'እምነት_ተከታይ', 'የእንኳን_ደረሰ', 'መልእክት', 'አለፈ'],
#  ['አዲስ',
#   'አቶ',
#   'ሬድዋን_ሁሴን',
#   'ሹመትመንታ',
#   'መንገድ',
#   'ቆመ',
#   'የስልጤ',
#   'ምርጫ',
#   'እመለስባታለው',
#   'ጠበቀ'],
#  ['አፋር',
#   'ወጣት',
#   'ተላለፈ',
#   'ቸኰለ',
#   'መልእክት',
#   'አፋር',
#   'ወጣት',
#   'አማራ',
#   'ክልል',
#   'ርእሰ',
#   'መስተዳድር',
#   'ክልል',
#   'ድርግ',
#   'ጉብኝት',
#   'ተቃወመ',
#   'ሰመራ',
#   'ሉሲ',
#   'አደራ',
#   'ልክ',
#   'አአ',
#   'ሰአት',
#   'ተገኛኘ',
#   'አሉ'],
#  ['ጀመረ',
#   'ቃል',
#   'ነበረ',
#   'ቃል',
#   'ቀለም',
#   'ቀነበረ',
#   'ቃል',
#   'ቀለም',
#   'ተግባር',
#   'ኖረ',
#   'መእራፉን',
#   'ጨረሰ',
#   'ቋጠረ'],
#  ['ቤት', 'ጥቃት', '–', 'ያለሰሚ', '–', 'ያለተመልካች'],
#  ['ሪፖርት', 'ፈረሰኛ', 'ምአም', 'አናብስትን', 'ረታ', 'አሸናፊነት_መለሰ'],
#  ['የህወሀት',
#   'ማእከላዊ',
#   'ኮሚቴ',
#   'አባል',
#   'አቶ',
#   'ጌታ',
#   'ረዳ',
#   'ትናንት',
#   'በድምጺ',
#   'ወያነ',
#   'ቴሌቪዥን',
#   'ህወሀት',
#   'ቀጣይ',
#   'እጣ_ፈንታ',
#   'ተናገረ',
#   'ተባለ',
#   'ማህበራዊ',
#   'ሚዲያ',
#   'ተሰራጨ',
#   'ዜና',
#   'ሀሰተኛ'],
#  ['"ኤርትራውያን',
#   'ስነ',
#   'ጥበበኛታት',
#   'ንናይ',
#   'ጎደና',
#   'ስነጥበብ',
#   'ክንደፍኣሉ',
#   'ይግባእ',
#   'ንዘሎና',
#   'ሀብታም',
#   'አራ',
#   'ብቕርጻ',
#   'ብቕብኣን',
#   'ስነ',
#   'ጽሁፍ',
#   'ክንትርኾ',
#   'ኣሎና',
#   'ነፍሲ',
#   'ወከፍ',
#   'ጎደና',
#   'አራ',
#   'ክንስንደሉ',
#   'ዝኽእል',
#   'እዩ"'],
#  ['አይ',
#   'አየ',
#   'ስምንተኛ',
#   'ክፍል',
#   'ዘለቀ',
#   'ሾመ',
#   'መልስ',
#   'እኮ',
#   'እዛው',
#   'ቀይ',
#   'ስምር',
#   '"ከጊዜው',
#   'ነባራዊ',
#   'ጋ',
#   'ተራመደ',
#   'አለቀ'],
#  ['ሀገር', 'ቀፈፈ', 'ብሄራዊ', 'እሴት', 'ሰላም', 'ምክር_ቤት', 'ተቋቋመ'],
#  ['ሰአት', 'የቴሌቭዥን', 'መርሀግብሩ', 'ተጀምሯልከዮድ', 'አቢሲንያ', 'ብስር', 'ዝግጅት'],
#  ['አይነት', 'ወሬ', 'ረገበ'],
#  ['የበታችነት',
#   'ስሜት',
#   'ክርር',
#   'ሰከረ',
#   'መጣ',
#   'መስጂድህን',
#   'ቅጥል',
#   'ተናገረ',
#   'መለሰ',
#   'አገባቹ',
#   'ትላለህያንተን',
#   'አይነት',
#   'ለቀለቀ',
#   'ምስጋና',
#   'ፈለገ',
#   'ታገለ',
#   'አባት',
#   'አጐነበሰ',
#   'ቻለ'],
#  ['የአባገዳ',
#   'ልጅ',
#   'ጠሚር',
#   'ዶር_አብይ_አህመድ',
#   'ጉጂ',
#   'አባገዳ',
#   'ተመርቀዉ',
#   'ካላቻ',
#   'አሰረ',
#   'ዶር',
#   'ደስ'],
#  ['እገዛ',
#   'ጓደኛ',
#   'ገደለ',
#   'ኋላ',
#   'ስሜት',
#   'ይሄ',
#   'ደሞ',
#   'መራ',
#   'ዘመን',
#   'አየ',
#   'አወቀ',
#   'ግልብነትግልፍተኝነት',
#   'ጉዳይ',
#   'ጥርእ',
#   'ረጋ',
#   'አመነ',
#   'ሰላም',
#   'ረገጠ',
#   'ተቻለ'],
#  ['ሰኔ',
#   'ቱን',
#   'ፍንዳታ',
#   'ተመለከተ',
#   'አሜሪካ',
#   'ላቀ',
#   'ተጠረጠረ',
#   'አሻራ',
#   'ውጤት',
#   'ጤና',
#   'ጥበቃ',
#   'ሚንስቴር',
#   'ነካ',
#   'እጅ',
#   'ቢገልጽልንግራ',
#   'ገባ',
#   'እኮ'],
#  ['በኤክሳይዝ',
#   'ታክስ',
#   'ሰበብ',
#   'ታየ',
#   'ዋጋ',
#   'ንረት',
#   'ተነሳ',
#   'ዝብእ',
#   'ገበያ',
#   'ስርአት',
#   'መንግስት',
#   'አበለ'],
#  ['አብይ', 'ራስ', 'ጀዋርን', 'ጠቀመ', 'አረገ', 'ተጠያቂዉ', 'አብይ', 'ነዉ'],
#  ['ልክ',
#   'ጋን',
#   'ዉስጥ',
#   'እንቁራሪት',
#   'ነዉ',
#   'ትንሽዬ',
#   'ብርሀን',
#   'አየ',
#   'ኖራ',
#   'ጋን',
#   'ወጣ',
#   'እቃ',
#   'ተቻለ',
#   'እንደጀዋር',
#   'ኬኛ',
#   'ቁጭ',
#   'ደሞ',
#   'ለቀቀ',
#   'ጀዋር',
#   'መንፈስ',
#   'የሚኒሊክ',
#   'ነዉ',
#   'እንቁራሪቷች',
#   'ልክ',
#   'ግብእ',
#   'አመነ'],
#  ['ጥንብ_ዘረኛ', 'ጠፋ', 'መርዝ'],
#  ['ወያኔ', 'ጣለ', 'ድርሻ', 'ነበረ', 'ወደቀ', 'ጉራ', 'ነዛ', 'በቀር'],
#  ['መኪና',
#   'ብዛት',
#   'ሚልየን',
#   'ደረሰመ',
#   'ገረረ',
#   'ግን',
#   'አማካይ',
#   'አመት',
#   'ከዎች',
#   'ትራፊክ',
#   'አደጋ',
#   'ህይወት',
#   'አለፈ'],
#  ['"የእነዛ',
#   'ምስኪን',
#   'ንጹሀን',
#   'ምንዱባን',
#   'ነፍሳት',
#   'ቀጠፈ',
#   'ህይወት',
#   'ረሳ',
#   '"',
#   'ቀን',
#   'ጀምበር',
#   'ዘመዳሞች',
#   'ፉክክር',
#   'አብይ_አህመድ',
#   'የአይኤስ',
#   'ወኪል',
#   'በሆነዉ',
#   'ግለሰብ',
#   'ፈጀ',
#   'ንጹሀን',
#   'ኢትዮጵያዊ'],
#  ['ሰለቸ',
#   'ጌታ',
#   'አውሬነት',
#   'ለወጠ',
#   'ደከመ',
#   'ደከመ',
#   'ጌታ_ሆይ',
#   'አረ',
#   'አይነት',
#   'ዘመን',
#   'ፔጅ',
#   'ሄደ',
#   'ያንን',
#   'ሙሉጭ',
#   'አረገ',
#   'ሰደበ',
#   'ሰደበ',
#   'ቀላ',
#   'ወይስ',
#   'ያንን',
#   'ፔጅ',
#   'አየ'],
#  ['ልክ',
#   'ቃል',
#   'ቅንነት',
#   'ገመተ',
#   'ቻለ',
#   'ቅንማ',
#   'ኪራይ',
#   'ሰብሳቢነኝ',
#   'በኢትቪ',
#   'ቀረጸ',
#   'ዶክሞንተሪ',
#   'የሚሰርቡህ'],
#  ['ሞተ', 'ጌታ_ሆይ', 'ኧረ'],
#  ['ፎከረ',
#   'ፓርቲ',
#   'ስብስብ',
#   'ቡድን',
#   'ወቀረ',
#   'ፋና',
#   'ዋልታ',
#   'ኢቲቪ',
#   'አጠቃላይ',
#   'ሀብት',
#   'ሚዲያ',
#   'ባለቤትነት',
#   'ጠቀመ',
#   'ጥርት',
#   'ጽድት',
#   'መስመር',
#   'እንዲሰመር',
#   'ታገለ',
#   'አለባቸው'],
#  ['ኦሮሞ', 'ተማረ', 'ከብት', 'ነዉ', 'አያስተዉልም', 'ጥንብ_ዘረኛ', 'ናቸዉ'],
#  ['እየሱስ_ክርስቶስ',
#   'ድንግል_ማርያ',
#   'ወለደ',
#   'ስጋ',
#   'ዳዊት',
#   'ዘር',
#   'ወለደ',
#   'ልጅ',
#   'ሀጢአት',
#   'እዳለመክፈል',
#   'ፔድ',
#   'ውይ*',
#   'ቻለ'],
#  ['ጌታ',
#   'እናት',
#   'ንጺህተ',
#   'ንጹሀን',
#   'ቅድስተ',
#   'ቅዱስ',
#   'ድንግል_ማርያ',
#   'አኔ',
#   'ሀጢያተኛ',
#   'ልጅ',
#   'ገባ',
#   'ሳበ',
#   'ሰራ',
#   'ልጅ',
#   'ቃልኪዳን',
#   'በለጠ',
#   'አሰበ',
#   'ሰአሊለነ',
#   'ቅድስት'],
#  ['አምላከ',
#   'ቅዱስ',
#   'ኡራኤል',
#   'መልአክ',
#   'ቀን',
#   'የተበረከና',
#   'ቀደሰ',
#   'ድርግ',
#   'ሰላም',
#   'አደረ',
#   'ሰላም',
#   'ዋለ',
#   'አገር',
#   'ዳር',
#   'ሰአት',
#   'መሀል',
#   'ገነት',
#   'ድርግ',
#   'ጠበቀ',
#   'አሜን'],
#  ['ጥር', 'ጊዜበተለይ', 'ቆመ', '"ተንቦገቦገች"'],
#  ['ኦሮምኛ',
#   'ለመደ',
#   'ድረስ',
#   'ኦሮሚኛ',
#   'ቻለ',
#   'ተረጐመ',
#   'እስቲ',
#   'ፎቶ',
#   'ፓ',
#   'ሰላም',
#   'ፍቅር',
#   'ደስታ',
#   'ፈገግታ',
#   'ሰፈነ',
#   'አቢቹ',
#   'ከአቢቹም',
#   'ፈነጠቀ',
#   'ደስ',
#   'ነጌኒ',
#   'በዳዳ',
#   'መኖርደስይላል'],
#  ['መልካም', 'እሴት', 'አደገ', 'ችግር', 'ሰላም', 'ፈታ', 'ዜጋ', 'አበረ', 'ቆመ', 'ሀይማኖት', 'አባት'],
#  ['ሃሃሃሃ',
#   'ቀለደ',
#   'አመት',
#   'በሀላ',
#   'መሬት',
#   'ሚሊዮን',
#   'ገበየ',
#   'ዶላር',
#   'ቡልልልልል',
#   'ቀረ',
#   'ወቃ'],
#  ['አመሰ',
#   'አል',
#   'ከፋ',
#   'ቦረና',
#   'ሰላም',
#   'እነራስ',
#   'ጎበና',
#   'ሰጠ',
#   'አጣ',
#   'ድፍን',
#   'አበሻ',
#   'ለኡራኤል',
#   'ሰጠ',
#   'ጎበና',
#   'ጋሻ',
#   'ዘፈነ',
#   'ስመጥሩ',
#   'ጀግና',
#   'ራስ',
#   'ጎበና',
#   'ይ'],
#  ['መንግስት',
#   'ግድብ',
#   'ዙሪያ',
#   'ተደረገ',
#   'ድርድር',
#   'ከፍተኛ',
#   'ጥንቃቄ',
#   'ድርግ',
#   'ገባ',
#   'ምክናያቱም',
#   'አሜሪካ',
#   'ግብጽ',
#   'የማታዳለበት',
#   'ምክንያት',
#   'ለም'],
#  ['ደከመ',
#   'ጊዜ',
#   'ግፍ',
#   'ወሰደ',
#   'ባህር_በር',
#   'ጊዜ',
#   'ጉዳይ',
#   'መለሰ',
#   'ቀረረ',
#   'ቻይና',
#   'ቦሊቪያ',
#   'ብዙ',
#   'ማረ'],
#  ['በተለይ',
#   'ምእራብ_ወለጋ',
#   'ግዛት',
#   'አመት',
#   'ድፍን',
#   'አመት',
#   'ሙሉ',
#   'ኦነግ',
#   'ነጻ',
#   'መንግስት',
#   'ልጅ',
#   'ወታደርነት',
#   'ሲመለምል',
#   'ትምህርት',
#   'ቤት',
#   'ጭምር',
#   'ወታደር',
#   'ካምፕ',
#   'ድርግ',
#   'ተናገረ',
#   'ጠፋ'],
#  ['ቲሽ',
#   'ጨለምተኛ',
#   'ዱቄት',
#   'ቆመ',
#   'እንዴ',
#   'ጊዜ',
#   'ነጐደ',
#   'አሉባልታ',
#   'ቀቀለ',
#   'በላ',
#   'ልደት',
#   'መጣ'],
#  ['እረ', 'እረፍት', 'አረገ', 'ይሄ', 'ደገመ', 'ስራ'],
#  ['ቁልጭ', 'መኩሪያ', 'እኮ'],
#  ['ክፉ', 'ተናግረውክፉ', 'አናገረ', 'ቀረ', 'በየነ', 'አስኮንኞች', 'እኮ', 'ደም', 'ንጹህ'],
#  ['ያንች', 'ነጻነት', 'አማራ', 'ወሬኛ'],
#  ['ቅውቀት',
#   'ዛሬ',
#   'በሳ',
#   'ነበርብሬ',
#   'ከባድ',
#   'ሚዛን',
#   'ተግባር',
#   'አየ',
#   'አይጠገቤው',
#   'ኢንተርቪው',
#   'እውቀት',
#   'ገበየ',
#   'ዋለ',
#   'ብል',
#   'ገነነ',
#   'ቤሬን',
#   'መጠነ',
#   'ጋዜጠኛ',
#   'ግን',
#   'አገርቤት',
#   'መሰለ'],
#  ['ህዳሴ_ግድብ', 'የሶስትዮሽ_ውይይት', 'ካይሮ', 'ተካሄደ'],
#  ['ግል', 'ኡስታዝ', 'አቡበክር', 'አህመድ', 'ምጠ', 'ሚኒስትር', 'ስልክ_ደወለ', 'ጭምር', 'ትዝ'],
#  ['ጥር', 'ስራ', 'ደረሰ', 'ግኝ*', 'ቻለ'],
#  ['ይሄ', 'ዜና', 'ስብሰባ', 'ተደረገ', 'ፊት', 'ቻለ'],
#  ['አማራ',
#   'ክልል',
#   'ሰራ',
#   'በላ',
#   'መንገድ',
#   'ተንጠባጠበ',
#   'ረዘመ',
#   'ቈላ',
#   'ፍትሀዊነትን',
#   'ሰፈነ',
#   'አማራ',
#   'ክልል',
#   'አይነት',
#   'መንገድ',
#   'ፕሮጀክት',
#   'ጀመረ',
#   'አወቀ',
#   'የርመስተዳድር',
#   'መከረ',
#   'ግዛት',
#   'በላ'],
#  ['አስኬ',
#   'መልካም',
#   'ስራ',
#   'መሰከረ',
#   'ህውን',
#   'ክርስቶስ',
#   'ወንጀለኛ',
#   'ነዉ',
#   'ብለዉታል',
#   'መልካም',
#   'ድርግ',
#   'ድል',
#   'የእግዛቤር',
#   'ነዉ',
#   'እግዛቤር',
#   'ሁል',
#   'ጊዜ',
#   'መልካም',
#   'ሚያረገዉ',
#   'ነዉ',
#   'የሚሆነዉ',
#   'አይዞህ',
#   'ስር',
#   'ወደቀ'],
#  ['ብይ'],
#  ['ኢቲቪ',
#   'ውነት',
#   'ተናገረ',
#   'ጀመረ',
#   'ብልጋና',
#   'ፓርቲ',
#   'መጪወ',
#   'ግዜ',
#   'ብልግና',
#   'ፓርቲ',
#   'ጨለማ',
#   'ነዉ',
#   'ኢቲቪ',
#   'ውነት',
#   'ተናገረ',
#   'ጀመረ',
#   'ብልጋና',
#   'ፓርቲ',
#   'መጪወ',
#   'ግዜ',
#   'ብልግና',
#   'ፓርቲ',
#   'ጨለማ',
#   'ነዉ',
#   'ኢቲቪ',
#   'ውነት',
#   'ተናገረ',
#   'ጀመረ',
#   'ብልጋና',
#   'ፓርቲ',
#   'መጪወ',
#   'ግዜ',
#   'ብልግና',
#   'ፓርቲ',
#   'ጨለማ',
#   'ነዉ'],
#  ['ጎንደር',
#   'ዩኒቨርሲቲ',
#   'ቅጣት',
#   'ጣለ',
#   'ግለሰብ',
#   'ሁከት',
#   'ሰፋ',
#   '"ተማሪዎች',
#   'ክፍል',
#   'ገባ',
#   'ከለከለ',
#   'ትምህርት',
#   'ጀመረ',
#   'መራ',
#   'መምህር',
#   'ፈራ',
#   'ስለት',
#   'ግቢ',
#   'ያዘ',
#   'በመገኘት"',
#   'ጥረት',
#   'ድርግ'],
#  ['ወደደ', 'ነበረ', 'ዛሬ', 'ጠላ', 'ሰፌድ', 'ቆሎ', 'ዘገነሽ', 'ጉድ'],
#  ['ታብሌት',
#   'ኮምፒውተሮቹ',
#   'ስጦታ',
#   'ተገኘ',
#   'ወይስ',
#   'ገንዘብ',
#   'የተገዙየከተማ',
#   'አደረ',
#   'በጀት',
#   'ያዘ',
#   'ነበርወይስ',
#   'ወዘፈቀደ',
#   'ከንቲባ',
#   'ደገፈ',
#   'ወይስ',
#   'ዜና',
#   'ተሰራጨ'],
#  ['መልካም', 'ረጋ', 'ተጫወተ'],
#  ['ከንቱ', 'ኖረ', 'ሰመኝ', 'እድሜ', 'ፍቅር', 'ለመለመ', 'ግን', 'ደህና', 'ኑረዲን', 'ኢሳ'],
#  ['ሁል', 'ጊዜ', 'ጌታ', 'ደስ', 'በላ'],
#  ['አጠቃላይ',
#   'ፖሊሲ',
#   'ወጣ',
#   'ጨመረ',
#   'በኢትዮጲያ',
#   'ሙያ',
#   'ፈለገ',
#   'አገልግሎት',
#   'ቦታ',
#   'ተገኘ',
#   'ፖለቲካዊ',
#   'አስፈላጊነት',
#   'ኢትዮጲያ',
#   'ባለሙያ',
#   'በሯእንደተዘጋ',
#   'ተማረ',
#   'ሀይል',
#   'እጥረት',
#   'ደሞ'],
#  ['ሰላም',
#   'ወጣት',
#   'ስራ',
#   'አጥነት',
#   'ምክንያት',
#   'እጦት',
#   'ተሰቃየ',
#   'መሪ',
#   'ባይ',
#   'ግን',
#   'ልማት',
#   'መጣ',
#   'ዘና',
#   'ድግ',
#   'ድርግ',
#   'በጀት',
#   'ግብዣ',
#   'አለቀ',
#   'ነወ',
#   'ዘንድሮ',
#   'በተ',
#   'ቢሊዮን_ብር',
#   'ድግስ',
#   'ወጣ'],
#  ['ወለጋ',
#   'ጉዳይ',
#   '“አለባብሰው',
#   'ቢያራሱ”',
#   'አይነት',
#   '“በመንግስት”',
#   'በኦነግ',
#   'የተረገው',
#   'ድርድር',
#   'ግልጽ',
#   'ነበረ',
#   'አካላት',
#   'ሰማ',
#   'ቻለ',
#   'የኦነግ',
#   'ሰራዊት',
#   'ካምፕ',
#   'ገባ',
#   'ቀረ',
#   'በያለበት',
#   'ምሽግ',
#   'ያዘ',
#   'ተሸበረ',
#   'ጀመረ'],
#  ['አወቀ', 'ሀበሻ', 'ወንድ', 'ሀበሻ', 'ሴት', 'ያዉቃሉ'],
#  ['ንግግር',
#   'ጊዜ',
#   'አሜን',
#   'ብል',
#   'ደከመ',
#   'ለሁላችንም',
#   'መታ',
#   'ሁላችንንም',
#   'ኩል',
#   'አየ',
#   'ሀገር',
#   'ጋራ',
#   'ገነባ'],
#  ['ዳር',
#   'ቆመ',
#   'አየ',
#   'ጊዜ',
#   'ዳር',
#   'ቆመ',
#   'አየ',
#   'መብት',
#   'ተሰለፈ',
#   'ሰጠ',
#   'የኢዜማ',
#   'መሪ',
#   'ብርሀን_ነጋ',
#   'ፕሮፌሰር',
#   'ዛሬ',
#   'ነጋ',
#   'ቦንገር',
#   'ሆቴል',
#   'ተናገረ',
#   'ስብሰባ',
#   'እንደቅጠለ'],
#  ['በቃ',
#   'መረጃ',
#   'ግን',
#   'ለእንዳንተ',
#   'አይነት',
#   'አብይ',
#   'ራስ',
#   'ወጥቶእኔ',
#   'ገደለ',
#   'ጨበጨበ',
#   'ውጪ',
#   'ድርግ',
#   'ምክንያት',
#   'ፈጠረ',
#   'ንጹነት',
#   'ትሰብካለ',
#   'ሞተ',
#   'ቤተሰብ',
#   'ደረሰ',
#   'ቈረቈረ',
#   'መሰለ'],
#  ['እርግጠኛ', 'ፈለገ', 'ለመደ', 'ውሸት', 'ተናገረ'],
#  ['አዋሽ',
#   'ባንክ',
#   'የባለአክሲዮኖች',
#   'ኛ',
#   'ደበነ',
#   'ኛ',
#   'ድንገተኛ',
#   'ጠቅላላ_ጉባኤ',
#   'ወሰነ',
#   'በላ',
#   'ውሳኔዎቸ',
#   'ተላለፈ',
#   'ባንክ',
#   'ካፒታል',
#   'ቢሊዮን_ብር',
#   'ቢሊዮን_ብር',
#   'ኢንድያድግ',
#   'ወሰነ',
#   'ቦርድ',
#   'አባል',
#   'ምርጫ',
#   'ተካሄዷል'],
#  ['ብልጽግና', 'ብልግና'],
#  ['ምእራብ',
#   'ኦሮሚያ',
#   'ተገኘ',
#   'ወለጋ_ዞን',
#   'ምስራቅ',
#   'ወለጋ',
#   'ሆሮ',
#   'ጉዱሩ',
#   'ወለጋ_ዞን',
#   'ኢንተርኔት',
#   'ስልክ',
#   'አገልግሎት',
#   'ቈረጠ',
#   'አካባቢ',
#   'ነዋሪ',
#   'ተናገረ'],
#  ['ጥር',
#   'በኮሮና',
#   'ቫይረስ_ተጠረጠረ',
#   'የላብራቶሪ',
#   'ምርመራ',
#   'ደቡብ_አፍሪካ',
#   'ላከ',
#   'ነበረ',
#   'ዜጋ',
#   'ናሙና',
#   'ቫይረስ_ነጻ',
#   'ጤና',
#   'ሚኒስቴር',
#   'ሚንስትር',
#   'ዲኤታ',
#   'ተናገረ',
#   'ኮሮናቫይረስ'],
#  ['ሽሮ', 'ፍትፍት', 'ፈለገ'],
#  ['አቡነመርቆሪዎስ',
#   'አመት',
#   'ጀመረ',
#   'ጊዜ',
#   'ተናገረ',
#   'አመት',
#   'አንዳች',
#   'ቃል',
#   'አፍ',
#   'ወጣ',
#   'ቈየ',
#   'አቡነ',
#   'መርቆሪዎስ',
#   'ገና',
#   'አል',
#   'ምክንያት',
#   'ድርግ',
#   'ጀመረ',
#   'ጊዜ"',
#   'እግዚያብሄርይባርካችሁ',
#   '"የሚል',
#   'ቃል',
#   'ተናገረ'],
#  ['እንዲህም',
#   'ተቻለ',
#   'ጔደኛየ',
#   'አብርሀ',
#   'አየ',
#   '"',
#   'ጨቈነ',
#   'ነበረ',
#   'ጨቌኘህ',
#   'ለካ',
#   'ጭቁን',
#   'ነበርኩ"',
#   'ሳበ',
#   'ድርግ',
#   'በራ'],
#  ['ምርጫ_ጊዜ_ሰሌዳ',
#   'ተመለከተ',
#   'ቦርድ',
#   'ሰብሳቢ',
#   'ወሪት',
#   'ብርትኳን',
#   'ሚዴቅሳ',
#   'ቀረበ',
#   'ገለጻ',
#   'ምርጫ',
#   'ቀን',
#   'ወሰነ',
#   'ህገመንግስቱን',
#   'ድርግ',
#   'መልክ',
#   'ህገመንግስታችን',
#   'ንኡስ',
#   'አስቀመጠ'],
#  ['ስስ',
#   'ብልት',
#   'መረጠ',
#   'ትኩረት',
#   'ተሳበ',
#   'የሚያደረጉት',
#   'መንግስት',
#   'ትኩረት',
#   'ሰጠ',
#   'አደብ',
#   'ገባ',
#   'ቻለ',
#   'አሰበ'],
#  ['ሰበብ',
#   'ድርግ',
#   'ጎረቤት',
#   'ውድ',
#   'ሸጠ',
#   'ርካሽ',
#   'ገዛ',
#   'ፈለገ',
#   'ሳን',
#   'ፍራንሲስኮ',
#   'ዴ',
#   'ሽያጭ'],
#  ['ኣይይይ',
#   'መሬት',
#   'ላላ',
#   'አማራ',
#   'ኣዲስኣበባ',
#   'መንግስት',
#   'አስመራ',
#   'ትእዛዝ',
#   'ተቀበለ',
#   'እስቲ',
#   'ነገረ',
#   'ሰውየ',
#   'ክፋት',
#   'ማ',
#   'ሻእብያ',
#   'ክናንተ',
#   'ባሰ',
#   'ሀገር',
#   'የሚሰጥክ',
#   'አረፈ',
#   'ተቀመጠ'],
#  ['አጭበርብሮም', 'ተሸነፈ'],
#  ['ጀመረ',
#   'ሌሎችሁን',
#   'ሰደበ',
#   'እይነት',
#   'ተከለ',
#   'ድርግ',
#   'ላላ',
#   'ግን',
#   'እሺ',
#   'ሶ',
#   'ህውሀት',
#   'ብሄራዊ',
#   'ፓርቲ',
#   'ተቋቋመ',
#   'ዘር',
#   'ፖለቲካ',
#   'ቀጠለ'],
#  ['"',
#   'ሰዎች"',
#   'ኢንሻላህ',
#   'ኢራን',
#   'አሜሪካ',
#   'ተሸነፈ',
#   'ረገጠ',
#   'ሲበጠረቁ',
#   'እያዬሁ',
#   'ሀይማኖት',
#   'ጎሰኝነትኮ',
#   'ሀቅ',
#   'ደፈነ',
#   'ተወዳዳሪ'],
#  ['አየ',
#   'ችግር',
#   'አይነት',
#   'ግለሰብ',
#   'ተመለከ',
#   'ሎጂክ',
#   'ገባ',
#   'ሀሳብ',
#   'ከሞሞገት',
#   'ፍረጃ',
#   'ቀደመ'],
#  ['ደግ', 'ድርግ', 'አፍ_ከፈተ'],
#  ['ቀን',
#   'ገዛ',
#   'ደቂቃ',
#   'ደም',
#   'ተፍስሶ',
#   'ወሰደ',
#   'ደም',
#   'የአትክልቶችዎን',
#   'አፈር',
#   'ፈሳ',
#   'ቤት',
#   'ያጥለቀልቀዋል',
#   'ተቃወመ',
#   'ንጹሀን',
#   'ተመኘ',
#   'ደም',
#   'ነቃ',
#   'ሞት',
#   'መጠጠ',
#   'ግን',
#   'ሌላኛው',
#   'ህይወት',
#   'አለፈ'],
#  ['አትሌት',
#   'ሀይሌ',
#   'ጠቀመ',
#   'ሀገር',
#   'ሰራ',
#   'ደነቀ',
#   'እስቲ',
#   'ሀይሌ',
#   'ሜትር',
#   'ሮጠ',
#   'ተሸነፈ',
#   'ተመካ',
#   'ጀባ',
#   'በላ'],
#  ['ብልጽግና', 'ፓርቲ', 'አዲስ_አበባ', 'ንግድ', 'ማህበረሰብ', 'ውይይት'],
#  ['መንግስት',
#   'ዲሞክራሲ',
#   'ቀደደ',
#   'ሰማ',
#   'ድርግ',
#   'ደንብ',
#   'ተከተለ',
#   'አላማ',
#   'ገለጠ',
#   'ሀሳብ',
#   'ነጻነት',
#   'ከለከለ',
#   'መንግስት',
#   'ብልጽግና',
#   'ተወራ',
#   '"ጽ"ን',
#   'መሀል',
#   'ወጣ',
#   'ስማ',
#   'ትክክለኛ',
#   'ማንነት'],
#  ['ኢ',
#   'ዜ',
#   'ማ',
#   'ደስይለኝ',
#   'ሀሳባቹህ',
#   'ናደ',
#   'ዜጋ',
#   'ይሄ',
#   'ዘር',
#   'ፓለቲካ',
#   'ጠፋ',
#   'ለምለሚትዋ',
#   'ኢትዩጽያ',
#   'ብንእይ',
#   'ጥር',
#   'ናቅፋ',
#   'ሰሀል',
#   'ኤርትራ',
#   'በረሀ',
#   'ለኢትዪጽያችን',
#   'የወደቅ',
#   'ለኢትዪጵያ'],
#  ['ዷ', 'ባዮሎጂካል', 'ሴትናት'],
#  ['ፈጠረ', 'ሬጌ', 'ሙዚቃ', 'ሆን', 'ቀጣ', 'እኮ', 'እዮብ', 'መኮንን', 'ራስ', 'ወሰደ', 'ቀን'],
#  ['የሚስደስት', 'እውነት', 'ቡዙዎች', 'መነጽር', 'ብያስተካክሉ', 'መልካም'],
#  ['"ካቀድነው',
#   'ገታ',
#   'ፈታ',
#   'እቅድ',
#   'ጋ',
#   'ይሰናሰል',
#   'መለሰ',
#   'ለአጋቾቹ',
#   'ሰጥተናል"',
#   'ንጉስ_ጥላሁን',
#   '•••'],
#  ['ጉዳይ', 'አገር', 'ሰላም', 'ተቀመጠ', 'በቀል', 'የርስበርስ', 'ጦርነት', 'ቀሰቀሰ'],
#  ['ያየሰው',
#   'ሺመልስ',
#   'ደረሰ',
#   'አዘነ',
#   'ቃል',
#   'አላምረው',
#   'በኮን',
#   'ሀላፊ',
#   'ንጉስ',
#   'ጥላሁ',
#   'ግድያ',
#   'ማስፈራሪያ',
#   'ደረሰ',
#   'አወቀ',
#   'አብይ_አህመድ',
#   'መንግስት',
#   'ፍጹም',
#   'ኣፋኝነት',
#   'ተሻገረ',
#   'ያየሰው',
#   'ሸዋ'],
#  ['ተገኘ', 'መታ'],
#  ['አየ', 'ብዙ', 'ቀየረ', 'መልካም', 'አዲስ', 'አመት', 'ፍጼ'],
#  ['ጉዳይ', 'ሙስና', 'እያንዳንዱ', 'ሙስና', 'ጠየቀ', 'ደረሰ', 'ለም', 'ተባለ'],
#  ['ትራምፕ', 'ጥብጥቢ', 'ተጫወተ', 'ለም'],
#  ['ወላይታ',
#   'ሊቃውንት',
#   'አክቲቪስት',
#   'አየ',
#   'ከህወሀት',
#   'ድርግ',
#   'ግኑኝነት',
#   'ደገፈ',
#   'ተቃወመ',
#   'ምክኒያቱም',
#   'ዋስትና',
#   'ፍለጋ',
#   'ሴጣን',
#   'ሌሄድ',
#   'ቻለ'],
#  ['ብልጽግና',
#   'ፓርቲ',
#   'አዲስ',
#   'ፓርቲ',
#   'የኢህአዴግ',
#   'ውህድ',
#   'ኦቦ',
#   'በቀለ_ገርባ',
#   'ኤም',
#   'ኤን',
#   'ሰጠ',
#   'አየ'],
#  ['ቤሄሩን', 'ደገፈ', 'ሌላዉን', 'ጣለ', 'አየ', 'ቻለ', 'ነዉ'],
#  ['“ጉራጌን', 'ፋቀ', 'ዋለ', 'ጠንካራ', 'ታታሪ', 'ኢትዮጵያዊ', 'የሚወጣው”'],
#  ['አካል', 'ጣረ', 'የንተ', 'ተደሰተ', 'ተጠረጠረ', 'አረገ'],
#  ['ነጻ', 'ጀመረ', 'ነጻነት', 'ትርጉም', 'ረዳ', 'ወሰነ'],
#  ['ብዙ',
#   'ግዜ',
#   'ለመነ',
#   'እምቢ',
#   'ወረደ',
#   'እግዜር',
#   'ገለጠ',
#   'ወረደ',
#   'አል',
#   'ቀን',
#   'ቆጥ',
#   'ተደርምሶ',
#   'አባ',
#   'ጐዳ',
#   'ቃሬዛ',
#   'ህክምና',
#   'ወሰደ',
#   'ብዙ',
#   'ወተወተ',
#   'አባት',
#   'ጆሮ',
#   'ጠጋ',
#   '"አሁንስ',
#   'እግዜርን',
#   'ደምብ',
#   'ሰሙት"',
#   'አሉ'],
#  ['ቈላ', 'ወንድ', 'በአል', 'ምንድነው', 'ለበሰ', 'አቦ', 'ቀና', 'ሀበሻ', 'ቀማ', 'ገዛ', 'እንዴ'],
#  ['ትክክል',
#   'ለአዲስአበቤዎች',
#   'ቆመ',
#   'ፖርቲ',
#   'ባልደራስ',
#   'እውነተኛ',
#   'ዲሞክራሲ',
#   'ድል_ዲሞክራሲ',
#   'ድል'],
#  ['ኤርትራ',
#   'ጉዳይ',
#   'በጠበጠ',
#   'ቀልድ',
#   'ዩኒቨርስቲ_ዘጋ',
#   'መንግስት',
#   'አልጋወራሹ',
#   'ተማሪ',
#   'ጨረሰ',
#   'ነውንዴ',
#   'ጠበቀ',
#   'ትምህርት',
#   'ከደበራቸው',
#   'አረፈ',
#   'እስቲ'],
#  ['"ህዝቡን', 'ዲሞክራሲ', 'ለመደ', '"', 'ቅድሚያ', 'ለመደ', 'አለባቸውይህ', 'ነጻ', 'ያወጣቸው"'],
#  ['ቱ',
#   'መራራ',
#   'ፓርቲ',
#   'ከበቡሽ',
#   'ዋጠ',
#   'መራራ',
#   'ፓርቲ',
#   '"ልጥ"',
#   'ዋጠ',
#   'ኧረ',
#   'ጀዌ',
#   'ከበቡሽ',
#   'ፓርቲ',
#   'ዋጠ',
#   'መስሚያ',
#   'ወይን',
#   'መራራ',
#   'መራራ'],
#  ['ትንሽ',
#   'ሀሳብ',
#   'ነጻነት',
#   'ገለጸ',
#   'መብት',
#   'ተከበረ',
#   'ማ',
#   'አየ',
#   'ነጻነት',
#   'ታገለ',
#   'ግማሽ',
#   'እብድ',
#   'ግማሽ',
#   'ዘረኛ',
#   'እየታዘብን'],
#  ['ግልጽ',
#   'ብሄር',
#   'መብት',
#   'ሩሲያ',
#   'አብዬት',
#   'አነሳ',
#   'ስታሊን',
#   'ተነሳ',
#   'መብት',
#   'ጉዳይ',
#   'አብዮት',
#   'ድጋፍ',
#   'የማግፕት',
#   'ኋላ',
#   'ታሊን',
#   'ገዳይ',
#   'ሆነግልጽ',
#   'ውይይት',
#   'ጠያቂ',
#   'ድምጥ',
#   'ቸገረ'],
#  ['እኮ', 'ኧረ', 'ቈረጠ', 'ግን', 'ተቀየመ', 'በቃ', 'ምክንያት', 'አመነ'],
#  ['ትግራይ',
#   'ህወሀት',
#   'ለየ',
#   'አየ',
#   'ተሻለ',
#   'ደሞ',
#   'ይሄንን',
#   'ጉዳይ',
#   'ክልል',
#   'ተጠቃ',
#   'ሰማ',
#   'ሰማ',
#   'ቀጣይ',
#   'ምርጫ',
#   'ሚፈታው',
#   'ጉዳይ',
#   'ክልል',
#   'ጐዳ',
#   'ሰቀቀ',
#   'ተደረገ',
#   'ስራ',
#   'ግን',
#   'ቆመ'],
#  ['ይቅርታ', 'መቀሌ', 'አለቀ', 'መሰለ'],
#  ['ቤተሰቦችሁ', 'ወደቃሌቲ', 'አረመ', 'ቤት', 'ገባ'],
#  ['በጋ', 'ዘረፈ', 'አገር', 'አንፎጋገር'],
#  ['አገር'],
#  ['መረጃ',
#   'መንጋ',
#   'ጀመረ',
#   'የሻሪያ',
#   'ፍርድ',
#   'ቤት',
#   'አዋጅ',
#   'ተቋቋመ',
#   'ቀዳማዊ',
#   'ሀይለ',
#   'ስላሴ',
#   'ናቸው"',
#   'መረጃ',
#   'ጉልጉሎ',
#   'ውጥእ',
#   'አቻ'],
#  ['ምርጫ',
#   'ፊት',
#   'ልክ',
#   'አሰበ',
#   'ነውእንበልና',
#   'የነጃዎር',
#   'ፖርቲ',
#   'መንግስት',
#   'መሰረተ',
#   'ወንበር',
#   'ጠራ',
#   'ተንከትክቶ',
#   'ሳቀ',
#   'እናየለን'],
#  ['አይ', 'ሳሙኤል', 'እቃ', 'በላ', 'መፖሰት', 'አስተማረ', 'ጠረገ', 'በላ', 'መጣ'],
#  ['አወቀ',
#   'ሰወች',
#   'እስልምና',
#   'መሰለ',
#   'በጭራሽ',
#   'ሰይጣናዊ',
#   'ዛር',
#   'አለያም',
#   'አየ',
#   'ጭፋ',
#   'አታላይ'],
#  ['"እኔ',
#   'ሶሻል_ሚዲያ',
#   'ሚዲያ',
#   'ቸኰለ',
#   'ወጣ',
#   'ተናገረ',
#   'ገና',
#   'አል',
#   'መልእክት_ተላለፈ',
#   'ሙስሊም',
#   'መግለጫ',
#   'ጠበቀ',
#   'ተባለ',
#   'ተገፋፍቼ',
#   'መግለጫ',
#   'ሰጠ',
#   '"',
#   'አቶ',
#   'ተመስገን_ጥሩነህ',
#   'አፋር',
#   'ተናገረ'],
#  ['ሰላም',
#   'ፍትህ',
#   'ሀገር',
#   'ልማት',
#   'ግለሰብ',
#   'ወሰነ',
#   'ነውመንግስት',
#   'ለዲሞክራስ',
#   'ዲሞክራሲ',
#   'ወልደ',
#   'ደግፉው',
#   'ህይወት',
#   'አመጠ',
#   'ያዘ',
#   'ቀና',
#   'የትግራየኦሮሞና',
#   'ሲዳማ',
#   'በተክንክ',
#   'በታትክ',
#   'ጠርንፎ',
#   'ልማት',
#   'ከንቱ'],
#  ['አማርኛ',
#   'በጠገዴ',
#   'ታዳጊ',
#   'ግድያ',
#   'ተያያዘ',
#   'ተጠረጠረ',
#   'ያዘ',
#   'ክትትል',
#   'ቀጠለ',
#   'ወረዳ',
#   'ፖሊስ'],
#  ['ወቅታዊ',
#   'ደረጃ',
#   'ደረጃ',
#   'እርምጃ',
#   'ዶሎፊን',
#   'ለመደ',
#   'ቋንቋ',
#   'ጻፈ',
#   'ድርግ',
#   'ቪዲዮ',
#   'አይወርዱ',
#   'ሃጎስ',
#   'ዮጋ',
#   'ትርጉም',
#   'ሰጠ'],
#  ['ኮምቦልቻ',
#   'ሞጣ',
#   'ሙስሊም',
#   'ጉዳይ',
#   'ተመለከተ',
#   'ኮምቦልቻ',
#   'ታላቅ',
#   'ሰላማዊ_ሰልፍ',
#   'ተካሄደ',
#   'ተገኘ'],
#  ['ዛሬ',
#   'አርማጭሆ',
#   'ህጻን',
#   'የታገተባቸው',
#   'ቤተሰብ',
#   'ነገረ',
#   'ከለሊት',
#   'ጀመረ',
#   'መንግስት',
#   'ስልክ',
#   'ዶለ',
#   'መንግስት',
#   'ጸጥታ',
#   'አካል',
#   'ደረሰ'],
#  ['ረጋ', 'ሀገር', 'ምርጫ', 'ፈለገ'],
#  ['እግዚአብሄር', 'ኢትዬጵያንና', 'ይባርክከጠባቦችና', 'አክራሪ'],
#  ['አሜን', 'በረከት', 'ደረሰ'],
#  ['ኑ', 'ሰፈር', 'እቺን', 'ገረመ', 'ተመካ', 'ወ', 'ቤት', 'አየ'],
#  ['ተባለ',
#   'ብሄር',
#   'ፌደራሊዝምን',
#   'ጠፋ',
#   'ያሬድ',
#   'ህገ',
#   'መንግስት',
#   'ከበረ',
#   'ረገድ',
#   'አማራ',
#   'ክልል',
#   'አከለ',
#   'ለም',
#   'ግን',
#   'ዘነዘና',
#   'የዞ',
#   'ተነሳ',
#   'አማራ'],
#  ['ውይ', 'ፈጠረ', 'እለት', 'ትዝ', 'በቃ', 'ልደት', 'ምናምን', 'ብዙ', 'ኧረ'],
#  ['ደረሰ', 'ከነመላው', 'ቤተሰብ', 'እሴኬው', 'ውድ', 'የኢትዬጲያ', 'ልጅ'],
#  ['አከከ',
#   'ቀየረ',
#   'መራ',
#   'አሜን',
#   'ቀጠለ',
#   'ካድሬ',
#   'መራ',
#   'ደገመ',
#   '"ከእኔ',
#   'አዋቂ"',
#   'ቱልቱላ'],
#  ['"ወይኔ', 'ቁርጭምጭሚቱ', 'አማረ', 'በጌታ"', 'ልብ', 'ደረቀ', 'ጠፋ'],
#  ['"በምን',
#   'ገለጸ',
#   'ትውልድ',
#   'አበሳ',
#   'ተንበረከከ',
#   'ብዛት',
#   'ተራመደ',
#   'ረሳ',
#   'አለፈ',
#   'ተለጐመ',
#   'አለፈ',
#   'ተከርችሞ',
#   'ጉልበት',
#   'ኮቴ',
#   'ምድር',
#   'አትሞ"',
#   'በስ'],
#  ['ይሄ', 'ሀረር', 'ልጅ', 'ጠበቀ', 'ሄደ', 'ደስታ', 'ወሰደ', 'እቅፍ', 'ድግፍ', 'ድርግ'],
#  ['ከሳ',
#   'ፒፕሉ',
#   'ሲያሽቋልጥ',
#   'ባለፈውሳምንት',
#   'ፍትህ',
#   'ቀላ',
#   'ቀለም',
#   'እሲኪያስብል',
#   'ቀይ',
#   'ለበሰ',
#   'ሶሻል_ሚዲያ',
#   'ተጨነቀ',
#   'ደሞ',
#   'ይሄ',
#   'ምነው',
#   'ሸዋ'],
#  ['ፍትህ',
#   'ሀገር',
#   'ደሞክራሲ',
#   'ዋሸ',
#   'ቀበሌ',
#   'ሊቀመንበር',
#   'ምንስቴር',
#   'መራ',
#   'ቅናተኛና',
#   'ቅመኛ',
#   'ፍትህ',
#   'ለስዳማ',
#   'ምሁር',
#   'ሙሉ',
#   'ያለጥፋታቸው',
#   'አሰረ'],
#  ['ደደብ',
#   'አረፋ',
#   'ጠማ',
#   'በላ',
#   'ከኤርትራው',
#   'ኣያቶላህ',
#   'ኢሰያስ',
#   'ወሰደ',
#   'ምክር',
#   'ገለጠ',
#   'ጀዝባና',
#   'አረፋ',
#   'በላ',
#   'አለም',
#   'አሰበ',
#   'ተታለለ',
#   'መሰለ'],
#  ['ኤክሳይስዝ', 'ታክስኤክሳይዝስታክስ', 'ነውአማርኛውን', 'ወግ', 'ተናገረ'],
#  ['እንደዚ', 'አይነት', 'ተረት_ተረት', 'እንዴ', 'ሰፈረ'],
#  ['ሰላም', 'በዛ'],
#  ['ብዙ', 'ሀቅ', 'ጠበቀ', 'አወቀ', 'ግን', 'ቸገረ', 'የአላህን', 'ሀቅ', 'ጠበቀ', 'አወቀ'],
#  ['በራ',
#   'ቀን',
#   'ደጋጓቹ',
#   'ጸጋ',
#   'ዘአብ',
#   'እግዚሀርያ',
#   'ወንጌል',
#   'ገበር',
#   'ጻድቅ',
#   'ንጹህ',
#   'ጠራ',
#   'ፈተነ',
#   'ተጋድሎ',
#   'አማረ',
#   'ፍሬ',
#   'ለአለም',
#   'በረከተ',
#   'ልዩ',
#   'ቀን'],
#  ['መኪና_አደጋ',
#   'ተከላከለ',
#   'አዲስ',
#   'እይታ',
#   'ቀረበ',
#   'ፈለገ',
#   'መኪና_አደጋ',
#   'ዜጋ',
#   'በላ',
#   'ዛሬ',
#   'ደህና',
#   'ቤት',
#   'ወጠን',
#   'ጤና',
#   'መለሰ',
#   'በዛ',
#   'ተጨነቀ'],
#  ['ወንድም', 'ሆይ', 'ውነተኛ', 'ጭምትነት', 'ጽድቅ', 'ንጹህ', 'ፍቅር', 'መልካም', 'ወሬ', 'በጎነ'],
#  ['ትዊተር',
#   'ላይክና',
#   'ሪትዊትን',
#   'ገንዘብ',
#   'ቀየረ',
#   'የካምፔይናችን',
#   'ተሳተፈ',
#   'ጠየቀ',
#   'አባሆይ',
#   'ጋሪያን',
#   'ገፋ',
#   'ከበደ'],
#  ['ልጅ', 'የመስከንን', 'ጥቅም', 'ቡና', 'ተማረ'],
#  ['ሀገር', 'መብቃቶ', 'ያሰደሰታል', 'እግዚአብሄር', 'ተመሰገነ', 'አሜን'],
#  ['ምክትል',
#   'ከንቲባ',
#   'ታከለ_ኡማ',
#   'ቢሮ',
#   'ተዘጋጀ',
#   'ቤት',
#   'ስር',
#   'ተቋም',
#   'ተጠሪነት',
#   'ዞረ',
#   'አለም',
#   'ባንክ',
#   'ከተማ',
#   'ልማት',
#   'ቤት',
#   'ሚኒስቴር',
#   'ድርጊት',
#   'ተቃወመ'],
#  ['ሊቢያ', 'ጦር', 'ሰለጠነ', 'ተቋም', 'ደረሰ', 'ጥቃት', 'ገደለ'],
#  ['ድርጅት',
#   'ተቋቋመ',
#   'አላማ',
#   'ውጪ',
#   'ተንቀሳቀሰ',
#   'ዜና',
#   'ሰማ',
#   'እኝህ',
#   'የምያክል',
#   'ጉመት',
#   'ፖለቲከኛ',
#   'ኢትዮጵያዊ',
#   'ተወዳጀ',
#   'ከነፍሰበላው',
#   'ጃዎር',
#   'ይመሰጥራልበነፍስ',
#   'ማጥፉት',
#   'ሴራ',
#   'አዋሽ',
#   'ባንክ',
#   'በላ'],
#  ['ገረመ',
#   'አቢ',
#   'ንጹህ',
#   'ሰብአዊ',
#   'ደሞክራስያዊ',
#   'የሚናገረውታድያ',
#   'ኢሳይያስ',
#   'ወደደ',
#   'አከለ',
#   'ፍቅር',
#   'አክብሮት',
#   'የሚያሳየውኢሳይያስኮ',
#   'ደሞክራሲ',
#   'ፈለገ',
#   'አምባገነን',
#   'ጨቈነ',
#   'መሪ'],
#  ['አማራ',
#   'መገናኛ',
#   'ብዙ',
#   'ዛሬ',
#   'አክሱም',
#   'አገውኛ',
#   'ትርጉም',
#   'ውሀ',
#   'ሹም',
#   'አል',
#   '"አማራ',
#   'መገናኛ',
#   'ብዙሃን"',
#   'ጉራጊኛ',
#   'ትርጉም',
#   'አይነት',
#   'አይነት'],
#  ['ጀመረ', 'ግዜ', 'መሰለ', 'ዛሬ', 'አየሁ'],
#  ['ለየ', 'እኮ', 'እግዚአብሄር', 'ጠቀለለ_ሚኒስትር', 'አረገ'],
#  ['ጀመረ',
#   'ትግል',
#   'ሲጠንቀቅ',
#   'ሰላም',
#   'ቤት',
#   'ገባ',
#   '“ቄሮ”',
#   'ተባለ',
#   'ምክንያት',
#   'ዛሬ',
#   'ነገሰ',
#   'አክሱም',
#   'ጺዮን',
#   'አራ',
#   'ክብረበአል',
#   'ጨፈረ',
#   'ታቦት',
#   'ገባ',
#   'ደግ',
#   'ሀገር',
#   'ወደደ',
#   '“ቄሮ”',
#   'ለአለም',
#   'መሰከረ'],
#  ['ኤችአይቪ', 'ክልል', 'ውጪ', 'ወረርሽኝ', 'ደረጃ'],
#  ['እገዛ',
#   'ሀገር',
#   'ጠላት',
#   'ተጠቃ',
#   'መደዴ',
#   'ጀግና',
#   'ሲያንቆለጳጵስ',
#   'ዋለ',
#   '"የ',
#   'ሉአላዊነት',
#   'ይነካል"',
#   'ተመጻደቀ',
#   'ይዳዳዋል',
#   'ሀገር',
#   'ሉአላዊነት',
#   'አንድነት',
#   'ኩል',
#   'ቈረቈረ'],
#  ['ሀበሻ', 'ልጅ'],
#  ['ፈላጊ', 'አሸርጋጅ', 'ንግድ', 'ቆመ', 'የለ'],
#  ['ዘገዩ',
#   'ጋሼ',
#   'ሃሃሃ',
#   'ድርግ',
#   'ቀረ',
#   'ቅጥል',
#   'አበረ',
#   'በቂ',
#   'ተመሰገነ',
#   'ሙስሊም',
#   'ጠንካራ',
#   'ድርግ'],
#  ['ከዩንቨርስቲዎቻችን',
#   'ጀመረ',
#   'ዎርክሾፖችና',
#   'ዌብናሮችን',
#   'ተባበረ',
#   'ጠነከረ',
#   'ተጨባጭ',
#   'ውጤት',
#   'በእምርታ',
#   'ተቀዳጀ'],
#  ['የእምዬ',
#   'ጣይቱ',
#   'የምድሪቷን',
#   'አፈር',
#   'ነካ',
#   'አሉላ',
#   'መንፈስ',
#   'የሰረጸኝ',
#   'ዘራፍ',
#   'ሀገር',
#   'ልጅ',
#   'ገብርዬ',
#   'ባልቻ',
#   'ልጂት',
#   'ወግድ',
#   'ነጫጭባ',
#   'እትትትትት',
#   'ኖችዬ'],
#  ['እንደሱማ', 'ቦታ', 'ኖረ'],
#  ['አለም', 'ጦርነት', 'እራስሽን', 'ዝግጅ*', 'ሰማ'],
#  ['በዚ', 'ዘመን', 'ከገንክ', 'ሚቆመዉ', 'ፎቶ', 'ቢቻ', 'ነዉ', 'ተገኘ', 'ከጎንክ', 'ሚቆመዉም', 'ነዉ'],
#  ['ግል', 'ኖረ', 'ግን', 'ደረደረ', 'ውጥእ', 'ዋጋ', 'ሸጠ'],
#  ['እግዚአብሄር', 'ሰጠ', 'መልካም', 'አል'],
#  ['ሙስሊም',
#   'ጉዳይ',
#   'አብይ_አህመድ',
#   'አቋም',
#   'ቀጠለ',
#   'አመነ',
#   'ወያኔ',
#   'ገባ',
#   'ቅርቃር',
#   'ገባ',
#   'ቀረ'],
#  ['ታከለ_ኡማ',
#   'አዲስ_አበባ',
#   'መሬት',
#   'ራስ',
#   'ፍቃድ',
#   'ቦታ',
#   'ተገኝ',
#   'እጅ',
#   'ስልክ',
#   'ሀብት',
#   'ሰጠ',
#   'ችግር',
#   'ፈጠረ',
#   'ከጥታ',
#   'እሳቸው',
#   'ዶለ',
#   'ድርግ',
#   'ሰራ',
#   'ብዙ',
#   'አሳማኝ',
#   'ረዳ',
#   'ሰማ'],
#  ['"መደመር', 'ተንፈረጠጠ', 'ሀሳብ', '"', 'ፕሮፌሰር', 'መስፍን', 'ወልደማርያም'],
#  ['አጭር',
#   'ጠቀሰ',
#   'ብክነት',
#   'አድራሻ',
#   'ቈጠረ',
#   'ንባብ',
#   'ሳይንትፊክ',
#   'ብክነት',
#   'ለየ',
#   'ኖረ',
#   'በዋናነት',
#   'የሚጠቀሱትበከተሞች',
#   'ውሰጥ',
#   'ለዉሰጥ',
#   'ዘረጋ',
#   'አየ',
#   'ውሀ',
#   'ብክነት',
#   'ጠቀሰ'],
#  ['አባት', 'ተመሰገነ'],
#  ['ደስ',
#   'ውድ',
#   'ጠቀለለ',
#   'ሚኒስትሪያችን',
#   'እግዚአብሄር',
#   'ተገኘ',
#   'ባረከ',
#   'ነገዎትን',
#   'ብርሀኑ',
#   'በራ',
#   'ሰለሞን',
#   'ጥበብ',
#   'ባረከ',
#   'አሜን'],
#  ['ዉድ',
#   'ምንያህል',
#   'በሀላ',
#   'ስጦታው',
#   'አገልግሎት',
#   'ነዉ',
#   'ጠቀመ',
#   'ግን',
#   'የዛሬዉን',
#   'ስጦታ',
#   'ጨረሰ',
#   'ገዛ',
#   'ጥቅል',
#   'አገልግሎት',
#   'ጠቀመ',
#   'ቀጠለ',
#   'ተመሰገነ'],
#  ['ተናገረ', 'ቀፈፈ', 'ሳተ', 'እዉነት', 'ለመደ'],
#  ['ጋዜጠኛ',
#   'ሸረሞጠ',
#   'ሴሌክቲቭ',
#   'አታካቸውን',
#   'ተመለከተ',
#   'ሀገር',
#   'ጥቅም',
#   'አሽከርነት',
#   'የቆማቹ',
#   'ህሊናቢስ',
#   'እንደሆናቹ',
#   'ረዳ',
#   'እዚያዉ',
#   'ካምፕ',
#   'ጀዌር',
#   'ጸጋ',
#   'አርአርሳ',
#   'ገቢሳ',
#   'ግም',
#   'ጉተማ',
#   'ተናገረ',
#   'አወቀ',
#   'መሰለ'],
#  ['በመጭው', 'ምርጫ', 'አማራ', 'ክልል', 'ተሸነፈ', 'ሸር', 'አደገ', 'ተሻለ', 'ድምጽ', 'አጋር'],
#  ['ሳበ', 'ቀጠለ', 'ደማ', 'ደግ', 'አባት', 'አማራ'],
#  ['ከረዩ',
#   'አርጎባ',
#   'አፋር',
#   'ለነብስ',
#   'ፈለገ',
#   'አቅም',
#   'ላጠ',
#   'ተመቸ',
#   'ግጥም',
#   'ጠቀመ',
#   'ዳጠ',
#   'ከረዩ',
#   'አጉል',
#   'አስቸጋሪ',
#   'ፈታ',
#   'አርጎባ',
#   'ድረስ',
#   'ሄደ',
#   'ነጠቀ',
#   'ግመል',
#   'ወሰደ'],
#  ['ዋሸ', 'ግልጽ', 'ጥያቄ', '"ምን', 'ያክል"'],
#  ['ወልቂጤ_ከተማ', 'ስድስተኛ', 'ሳምንት', 'ጨዋታ', 'ሜዳ', 'ተከናወነ'],
#  ['እሺ', 'ስድብ', 'ቀረ', 'ንግር'],
#  ['ድል', 'ዴሞክራሲያ'],
#  ['መልካም',
#   'ዜና',
#   'ደቡብ_አፍሪካ',
#   'የላብራቶሪ',
#   'ምርመራ',
#   'ላገ',
#   'አራት',
#   'ተጠረጠረ',
#   'ውጤት',
#   'ከኖቭል',
#   'ኮሮና_ቫይረስ',
#   'ነጻ',
#   'ረገጠ'],
#  ['ደሀ',
#   'በደለ',
#   'ከበበ',
#   'ሰውሳያስገድል',
#   'ልዩ',
#   'ጥቅም',
#   'ውድልድል',
#   'ዱላ',
#   'ጨበጠ',
#   'መንገድ',
#   'ዘጋ',
#   'እልፍ',
#   'ነጻ_ውጥእ',
#   'አእላፉን',
#   'መንጋ',
#   'አንቀጠቀጠው',
#   'እስክንድር_ነጋ',
#   'ኰራ',
#   'ሲያዩክ',
#   'ደም',
#   'ብዛት',
#   'ከፍ',
#   'ድንቄ',
#   'ለውጥ'],
#  ['እንዲህም',
#   'አይነት',
#   'ቅንነት',
#   'ችግር',
#   'ግን',
#   'መራራ',
#   'አፍ',
#   'ወጣ',
#   'ቃል',
#   '"ጃዋር',
#   'ኦሮሞ',
#   'ትግል',
#   'አንድምእራፍ',
#   'ከፍ',
#   'ያደረገነው"',
#   'አመነ',
#   'ሀቅ',
#   'መራራ',
#   'መራ',
#   'ጃዋር',
#   'መሪነት',
#   'ቦታ'],
#  ['ድሬዳዋ',
#   'ሀገረ',
#   'ስብከት',
#   'ጅቡቲ',
#   'አብያተ',
#   'ክርስቲያናት',
#   'ሊቀ',
#   'ጳጳስ',
#   'ብጹእ',
#   'አቡነ',
#   'ዳንኤል',
#   'አረፈ'],
#  ['ጠሚር',
#   'አብይ_አህመድ',
#   'አማ',
#   'ደገመ',
#   'ተናገረ',
#   'ሰማ',
#   'እውነት',
#   'እውቀት',
#   'ንኛ',
#   'ክፍል',
#   'ጥንቅቅ',
#   'ዶክትሬት',
#   'በቆረጣ',
#   'ተገኘ',
#   'ራስ',
#   'ኢታማዦር',
#   'ሹም',
#   'በሻጥር',
#   'ገደለ'],
#  ['ዛሬ',
#   'በአል',
#   'ቀን',
#   'ጨቀጨቀ',
#   'ብይ',
#   'ቃል',
#   'ገባ',
#   'ነበረ',
#   'ደግነት',
#   'ውርእ',
#   'ላፈ',
#   'እግዜር',
#   'ተቈጣ',
#   'መሰለ',
#   'ሰማ',
#   'ተመሰገነ',
#   'ስል',
#   'ቃል',
#   'አፈረ'],
#  ['ራስ',
#   'የማግሰፍ',
#   'ስልት',
#   'እልክ',
#   'ስያልፍ',
#   'ዉሸት',
#   'ይታወቃልእኔ',
#   'ላቀ',
#   'ሀሳብ',
#   'ራስ',
#   'አምባገንነት',
#   'ነዉየሚያገዳድልም',
#   'መንግስት',
#   'ጀሌ',
#   'ወያኔ',
#   'ናቸዉአዉንም',
#   'የሚንኖረዉ',
#   'ጥበብ',
#   'ነዉጉልቻ',
#   'ቀየረ',
#   'ወጥ',
#   'ጣፈጠ'],
#  ['አገር',
#   'ነሳ',
#   '“የብሄር',
#   'ጥያቄ”',
#   'ብሄር',
#   'ድርጅት',
#   'በህብረ',
#   'ብሄር',
#   'ድርጅት',
#   'መልስ',
#   'ተገኘ',
#   'አብዛኛ',
#   'ብሄር',
#   'ድርጅት',
#   'ግን',
#   'ጥያቄ',
#   'መለሰ',
#   'ጥያቄ',
#   'ነገደ',
#   'ቀና'],
#  ['ህይወት',
#   'ታሪክ',
#   'አወቀ',
#   'ሳተ',
#   'ምቀኝነት',
#   'ውነት',
#   'መሰለ',
#   'ጻፈ',
#   'መሰለ',
#   'ድርግ',
#   'ፈተነ',
#   'ውነተኛ',
#   'ስፍራ',
#   'ሊ'],
#  ['ወረረ',
#   'ሰናይት',
#   'ነውረኛ',
#   'ሴት',
#   'ተማረ',
#   'ትውልድ',
#   'ገደለ',
#   'ፈጠረ',
#   'ተሻለ',
#   'ግን',
#   'ወልደ',
#   'ዘር',
#   'ተካ',
#   'ልጅ',
#   'ዘር',
#   'ተካ',
#   'ጠፋ',
#   'ሰራ',
#   'ወንጀል',
#   'ፈጠረ',
#   'ስራ',
#   'ሰጠ'],
#  ['ቤቲ', '"', 'ቆንጆ', 'ነኝ"', 'ሚሚ', 'ስብሀት', 'ሰምታ•••', '"እኔም', 'ተስፋ', 'ነው"'],
#  ['ስኳር', 'ግፊት', 'መደሃኒት', 'በዛ', 'ድርግ', 'አይ', 'ዳኒ', 'ምስኪን'],
#  ['ተሻለ', 'ኸረ', 'ተሻለ', 'ዘፈን', 'ስማ', 'ጌት', 'ዳውን', 'አል', 'ያሁነያ'],
#  ['ዳነ', 'ዘከዘከ'],
#  ['ቴአትር',
#   'ስነጽሁፍ',
#   'ታሪክ',
#   'ልደት',
#   'እድገት',
#   'ቅጽ',
#   'ምርቃት',
#   'ሆቴል',
#   'አዲስ_አበባ',
#   'ፊት',
#   'ሽፋን',
#   'አመተ',
#   'ምህረቱ',
#   'ልብ',
#   'ይሏል',
#   '፻'],
#  ['አዲስ',
#   'ኤክሳይስ',
#   'ታክስ',
#   'ገባ',
#   'መኪና',
#   'ጣለ',
#   'አቀደ',
#   'አመት',
#   'ተገለገለ',
#   'አመት',
#   'ተገለገለ',
#   'አመት',
#   'ተገለገለ'],
#  ['እውቀት',
#   'ነጻ',
#   'ሀገር',
#   'መራ',
#   'ማጂ',
#   'ግል',
#   'እሰከ',
#   'ድረስ',
#   'አንደሚያውቃት',
#   'ተናገረ',
#   'ቻለ',
#   'ራስ',
#   'ተመነ',
#   'ልጅ',
#   'አመመ',
#   'ገጠመ',
#   'ተመረኰዘ',
#   'ጻፈ',
#   'ጥርጥር'],
#  ['ህወሀት',
#   'በላ',
#   'እግዚአብሄር',
#   'አመነ',
#   'ማህበረሰብ',
#   'ግራ',
#   'እጅ',
#   'ውጥእ',
#   'ብሄርተኛ',
#   'ግራ',
#   'ክርር',
#   'መራ',
#   'ሙዝ',
#   'ድረስ',
#   'ደረሰ',
#   'ውጪ',
#   'ደረሰ'],
#  ['ልክ',
#   'ክልል',
#   'ዞን',
#   'ምናምን',
#   'አሉ',
#   'አድገውኮ',
#   'ዩኒቨርሲቲ',
#   'ሄደ',
#   'ችግር',
#   'ፈጠረ',
#   'ተአምር',
#   'ሀሳብ',
#   'ሀገር',
#   'ሀገር',
#   'ሰፋ'],
#  ['ግብጽ', 'በናይል', 'ድርድር', 'ሄደ', 'ጠና', 'ጉዞ', 'ተዳረሰ', 'ተስፋ', 'ታፈሰ', '–', 'ፕሮፌሰር'],
#  ['አመት', 'ሞላ', 'ዲሞክራሲያዊ', 'መብት', 'ጠቀመ', 'እምቡር', 'እምቡር', 'መብት', 'ነዉ'],
#  ['አለፈ',
#   'ኦሮሚያ',
#   'ክልል',
#   'ቄለም',
#   'ወለጋ_ዞን',
#   'ሰዮ',
#   'ወረዳ',
#   'ጉቴ',
#   'ሰዮማ',
#   'ቀበሌ',
#   'ኖረ',
#   'አማራ',
#   'ወለደ',
#   'ታጠቀ',
#   'ገደለ',
#   'ሸሽስተው',
#   'ደንቢዶሎ',
#   'ከተማ',
#   'መጣ',
#   'ነዋሪ',
#   'ተናገሩታጣቂዎቹ',
#   'ሴት',
#   'አፈነ',
#   'ወሰደ'],
#  ['ምስራቅ_ጎጃም', 'ዞን', 'ገባ', 'መራ', 'ገቢ', 'አሰባሰብ'],
#  ['ፍላጎታችንኮ', 'ገደብ', 'አጣ', 'ለእግዜርም', 'አልተመቸን'],
#  ['ጀንጅኜ',
#   'አሳምኛታለው',
#   'እቃ',
#   'ይቺንማ',
#   'ትዳር',
#   'ተንከባከበ',
#   'ቈየ',
#   'መሀል',
#   'ቀን',
#   '"ቆይ',
#   'ቀድሞ',
#   'ገባ',
#   'ይመስልሀል"'],
#  ['ለሃግም', 'ለሃንግም', 'ምላሽ', 'ሰጠ', 'ብዙ', 'ፈጠረ', 'ግን'],
#  ['አማርኛ', 'እባክዎ', 'ሰማ'],
#  ['ተከተል', 'አይቀርማ', 'ጨረሰ'],
#  ['የውብዳርዬ', 'እግዜር', 'ተረፈ', 'ቆንጆ'],
#  ['ገረመ',
#   'ፖለቲካ',
#   'ፓለቲካ',
#   'ነዉ',
#   'ግን',
#   'እምነት',
#   'ጌእዝን',
#   'ኦሮሞዎቹ',
#   'ኰነነ',
#   'ቤተክርስቲያን',
#   'ተቃጠለ',
#   'ከሀናት',
#   'አረደ',
#   'ትግሬ',
#   'አክቲቪስትነ',
#   'ኩል',
#   'ከኦሮሞዉ',
#   'ወግ',
#   'ነዉ',
#   'ይሄንን',
#   'ፈረደ',
#   'አማራ',
#   'መኮነናቸዉ'],
#  ['ወላይታ',
#   'ሶዶ',
#   'ዩኒቨርሲቲ',
#   'ማስተማሪያ',
#   'ሪፌራል',
#   'ሆስፒታል',
#   'አጠቃላይ',
#   'ሆስፒታል',
#   'ግንባታ',
#   'ዲዛይን',
#   'ምክክር',
#   'መድረክ'],
#  ['አመነ', 'ጌታ', 'ብርታት', 'ሰጠ', 'ጠበቀ', 'መልካም', 'አል'],
#  ['ሴሚስተር', 'ፈረሰ'],
#  ['በለው', 'ታድያ', 'ሰላም', 'ተባለ'],
#  ['ስር',
#   'ክፋት',
#   'መስሪ',
#   'አይነት',
#   'ስይጣን',
#   'የተጠናዉታችሁ',
#   'እገዛ',
#   'ወገን',
#   'ገደለ',
#   'ቀን',
#   'ሌት',
#   'የምትባዝኑት',
#   'አበረ',
#   'አደገ',
#   'ትግራዬች',
#   'ደግ',
#   'ገራገር',
#   'አይነት',
#   'ምድር',
#   'መጣ',
#   'በምቅኝነት',
#   'የተተበተባችሁ'],
#  ['ባህር_ዳር', 'ከተማ', 'ወሰነ', 'ተጫዋች', 'ጉዳት', 'አጣ'],
#  ['ሴት',
#   'ልጅ',
#   'እናት',
#   'እናት',
#   'ልጅ',
#   'አባት',
#   'ተስፋ',
#   'ወንድም_እህት',
#   'ባሌ',
#   'ሚስት',
#   'ሀገር',
#   'ዜጋ',
#   'መንግስት',
#   'የተታፈኑት',
#   'ሴት',
#   'ተመለከተ'],
#  ['ልክ', 'ሚሰማ', 'እኮ'],
#  ['ተደራጀ'],
#  ['መተማ',
#   'ሶሮቃ',
#   'ተገኛኘ',
#   'ወዳጅ',
#   'አራንባና',
#   'ቆቦ',
#   'መረጃ',
#   'ቀረበ',
#   'ሀገር',
#   'አንጻር',
#   'አይነት',
#   'ፈጠረ',
#   'ተባለ',
#   'ቀረበ',
#   'ግን',
#   'አካባቢ',
#   'መረጃ',
#   'ያሳያ'],
#  ['ማንነት',
#   'ወሰን',
#   'ጉዳይ',
#   'ኮሚሽን',
#   'ጉዳይ',
#   'ብዙ',
#   'ተባለ',
#   'በህገመንግስቱ',
#   'ግልጽ',
#   'ፌደሬሽን',
#   'ምክር_ቤት',
#   'ሰጠ',
#   'ስልጣን',
#   'አንጻር'],
#  ['ኳስ', 'ጠለዘ', 'እንዴ', 'ጠቀመ'],
#  ['ደስ', 'አደጋ', 'ተከላከለ', 'ተነሳ', 'ግድ', 'ኢትዮጵያዊነት', 'እግዚአብሄር', 'ስጦታ', 'ድል'],
#  ['ኧረ',
#   'አምላክ',
#   'ምንድ',
#   'ልጅ',
#   'አለቀ',
#   'ዛሬ',
#   'ማረ',
#   'መኪና_አደጋ',
#   'በነውጠኞች',
#   'ህይወትቅቸውን',
#   'ላጠ',
#   'ተማረ'],
#  ['አማራ',
#   'ክልል',
#   'እስልምና',
#   'ጥላቻ',
#   'ልብ',
#   'እንዲጋልብ',
#   'አዶ_ሜዳ',
#   'ለቀቀ',
#   'ባለስልጣን',
#   'ድጋፍ',
#   'ተደረገ',
#   'ፍዳ',
#   'ከፈለ',
#   'ሙስሊም',
#   'አማራ',
#   'ወለደ',
#   'እገዛ',
#   'ልጅ',
#   'ቀረጠፈ',
#   'በላ',
#   'ክ'],
#  ['ወቸው', 'ጉድ', 'ተአምር', 'ሰራ', 'አሰበ', 'ጌታ'],
#  ['አከለ',
#   '"እስካሁን',
#   'ብዙ',
#   'ጉዳይ',
#   'መከረ',
#   'ግን',
#   'ስምምነት',
#   'ደረሰ',
#   'ድረስ',
#   'ክፍት',
#   'ነው"',
#   'ጻፈ',
#   'ዛሬ',
#   'ነገ',
#   'አዲስ_አበባ',
#   'ተካሄደ',
#   'ውይይት',
#   'ቴክኒክ'],
#  ['ልማት',
#   'ስራ',
#   'ተዘናጋ',
#   'ጦርነት',
#   'መፍትሄ',
#   'ሳበ',
#   'ሰላም',
#   'ኖረ',
#   'ሻ',
#   'ግብጽ',
#   'በተለይ',
#   'ደገመ',
#   'በዳይ',
#   'እሷው',
#   'በዳይ',
#   'ድርግ',
#   'አሜሪካ',
#   'አውሮፓ',
#   'አረብ',
#   'አለም',
#   'አፍሪካ',
#   'ከሰሰ',
#   'ተገኘ'],
#  ['ኧረ',
#   'ጣለ',
#   'አረጋ',
#   'ጥር',
#   'ከነ',
#   'አሻቡዋም',
#   'አጭር',
#   'ካልሲውን',
#   'ገድግዶ',
#   'ረገመ',
#   'ሊያ',
#   'ብሄራዊ'],
#  ['ዘፍጥረት',
#   'ማቱሳላም',
#   'ኖረ',
#   'ዘመን',
#   'ዘጠኝ',
#   'ስልሳ',
#   'ዘጠኝ',
#   'አመት',
#   'ሞተ',
#   'ላሜህ',
#   'ሰማንያ',
#   'አመት',
#   'ኖረ',
#   'ልጅ',
#   'ወለደ',
#   'ላሜህ',
#   'ኖረ',
#   'ዘመን',
#   'አርባ',
#   'አመት',
#   'ሞተ'],
#  ['ጉራጌ', 'አባት', 'እናት', 'ወለደ', 'ግን', 'ቀደመ', 'ብሬ', 'እሺ', 'አንቢቢ', 'እስኪ'],
#  ['እስርቤት',
#   'ምሁር',
#   'ሲሳይ',
#   'ተናገረ',
#   'ጠቀሰ',
#   'ወደደ',
#   '"ሲሳይን',
#   'ተገደደ',
#   'ደነቀ',
#   'ነው"',
#   'አንዱአለም',
#   'አራጌ',
#   'ዲሲ',
#   'ተደረገ',
#   'የእራት',
#   'ግብዣ',
#   'ተናገረ'],
#  ['መልካም'],
#  ['ምስክር',
#   'ይሄንን',
#   'ተገኘ',
#   'ቻለ',
#   'ሰአት',
#   'ብርሀን',
#   'ተሰማ',
#   'ጻፈ',
#   'የዱን',
#   '"የአማርኛ',
#   'መዝገበ',
#   'ቃላት"',
#   'ብር',
#   'ገዛ',
#   'አወቀ',
#   'በብላክ',
#   'መርካቶ',
#   'አሮጌ',
#   'ተራ'],
#  ['ውይ', 'ጆኒዬ', 'ወደደ', 'አክባሪ', 'እዛ', 'መለሰ', 'አየ', 'መሰለ', 'እኮ', 'አፍ'],
#  ['በክትክታ', 'ዙሪያ', 'ውይ*', 'አወቀ', 'ካለዋቁ', 'ቅጥልጥል', 'ጋብዘኖቷል', 'በዛ', 'ድምጽ', 'ሰጠ'],
#  ['ጸረ',
#   'ስለሆንክክርስቲያንም',
#   'ሙስሊም',
#   'አትወክልምበቃ',
#   'ጸረ',
#   'ነሀ',
#   'ምንምማድረግ',
#   'አይቻልምየሰዎች',
#   'ጠላት',
#   'የሰውሰይጣንነህስለዚህ',
#   'ክርስትያኑ',
#   'በስመአብብሎ',
#   'እማትቦ',
#   'ከለከለ',
#   'ሙስሊሙከተረገመው',
#   'ሰይጣን',
#   'በአላህ',
#   'እጠበቃለሁብሎ',
#   'ተከላከለ'],
#  ['ጥር',
#   'ውሳኔ',
#   'ብድር',
#   'ተጨናነቀ',
#   'አርፍው',
#   'ተማረ',
#   'ምግብ',
#   'ኖረ',
#   'ሳበ',
#   'ገደለ',
#   'ግዜ',
#   'ግኝ*',
#   'አፍሪካ',
#   'ሀገር',
#   'ተማረ',
#   'ዩኒቨርቲ',
#   'ማረ',
#   'አለባቸው',
#   'መከራ',
#   'አየ',
#   'ጥር',
#   'ጥጋበኛ'],
#  ['ምልክ', 'ምልዮን', 'ዋጋ'],
#  ['መልካ',
#   'ስራ',
#   'ጠረቀመ',
#   'ሸቀጥ',
#   'ወደደ',
#   'ወደደ',
#   'ወገን',
#   'በዛ',
#   'ጠቀመ',
#   'ቀን',
#   'እውስ',
#   'አላህ',
#   'መራ'],
#  ['በሬ', 'መሰለ', 'ነጂ', 'ደገመ', 'መንግስት', 'ዝም', 'ብየ', 'ሳበ', 'አቅም', 'እንጂሩ'],
#  ['ወሬ', 'መለስ', 'እየው', 'ግን', 'ሰሙ', 'ደረት', 'አጥንት', 'ስትዬ', 'መሰለ'],
#  ['አረ',
#   'ምንሼ',
#   'አዲስ_አበባ',
#   'ወጣት',
#   'ጠላ',
#   'ወጣት',
#   'እንዴ',
#   'አወቀ',
#   'ሚሊኒየም',
#   'ደረሰ',
#   'ዛሬ',
#   'ጎልማሳ',
#   'ስብሰባ',
#   'ተባለ',
#   'ቀላ'],
#  ['ሀምምም', 'ተጽእኖ', 'ፈጣሪነቱ', 'ቀነሰ', 'መልክ'],
#  ['“ጨዋነት',
#   'ጥላቻ',
#   'ረካ',
#   'ፍቅር',
#   'ዳበረ',
#   'በጎ_አድራጎት',
#   'እህት',
#   'ናት”',
#   'የአሴሲ',
#   'ቅዱስ',
#   'ፍራንሲስ'],
#  ['ኦሮሚያ',
#   'ሀይል',
#   'ጐለበተ',
#   'መሪነት',
#   'ክትት',
#   'በለጠ',
#   'ትኩረት',
#   'ድርግ',
#   'ረጅም',
#   'ጊዜ',
#   'ቅኝ',
#   'ግዛት',
#   'ድል'],
#  ['ወደቀ', 'ተባለ', 'ግን', 'ቅን', 'ተባለ', 'በላ', 'በርግጠኝነት', 'ጎንደሬ', 'አለበ'],
#  ['ተመለከተ',
#   'ተአምር',
#   'በደብረ',
#   'ሊባኖስ',
#   'አካባቢ',
#   'ተገኘ',
#   'ቀጸባ',
#   'ማርያ',
#   'ቤክ',
#   'ግራኝ',
#   'አህመድ',
#   'ግራ',
#   'እጅ',
#   'ወረወረ',
#   'ሲኖትራክ',
#   'ቻለ',
#   'ግዙፍ',
#   'ቋጥኝ',
#   'ድንጋይ',
#   'ደብር',
#   'ጨፈለቀ',
#   'ደነቀ'],
#  ['ደህና', 'ተኛ'],
#  ['ደረቅ',
#   'ውሸት',
#   'ተናገረ',
#   'አሰበ',
#   'ከባድ',
#   'ምንአልባት',
#   'ጠቀሰ',
#   'አሰበ',
#   'ህገመንግስት',
#   'ቀጠለ',
#   'ተሻለ'],
#  ['መኪና_አደጋ',
#   'ነፍጠኛ',
#   'ሰራ',
#   'አገራዊ',
#   'አፍራሽነትን',
#   'ደበቀ',
#   'ቻለ',
#   'ማህበረሰብ',
#   'ሄደ',
#   'ተመካ_አደጋ',
#   'ውርእ',
#   'ጆሮ',
#   'ዳባልበስ'],
#  ['ገባ',
#   'ተጽእኖ_አደረ',
#   'ብሮድካስቲንግ',
#   'ኮርፖሬሽን',
#   'አስተዳደር',
#   'በትግራኛ',
#   'ቋንቋ',
#   'ክፍል',
#   'ገባ',
#   'ተጽእኖ_አደረ',
#   'የትግራኛ',
#   'ክፍል',
#   'ባልደረባ',
#   'ቢቢሲ',
#   'ተናገረ'],
#  ['ግብር', 'ከፈለ', 'ቀና', 'ገባ', 'ተመለከተ', 'ለማ', 'ተናገረ'],
#  ['ታህሳስ', 'ትልቅ', 'ተቋም', 'የሳይበር', 'ጥቃት', 'አደጋ', 'ስጋት', 'ደረጃ', 'ግጥም', 'ተባለ'],
#  ['ፈረንጅ',
#   'ራስ',
#   'ችግር',
#   'ውርእ',
#   'አፍ',
#   'ችግር',
#   'የምንሰማበትት',
#   'ጆሮ',
#   'ሰጠ',
#   'ምኞት',
#   'መልካም',
#   'አዲስ',
#   'አመት'],
#  ['መራ',
#   'ፖለቲካ',
#   'ጨዋታ',
#   'ሰለባ',
#   'መልክ',
#   'ተቀባይነት',
#   'መንግስት',
#   'የታገቱ',
#   'መራ',
#   'ጉዳይ',
#   'ሰራ',
#   'ግልጽ',
#   'መረጃ',
#   'ሰጠ'],
#  ['ጣት', 'ቈረጠመ', 'ምግብ', 'ጥርግርግ'],
#  ['አለም',
#   'ካቶሊክ',
#   'መሪ',
#   'ተሳስቼለሁ',
#   'ይቅርታ',
#   'አረጋ',
#   'አል',
#   'አፍሪካ',
#   'መሪ',
#   'ሳተ',
#   'አረመ'],
#  ['ስራ',
#   'ሰራ',
#   'ሀላፊነት',
#   'ተጠያቂነት',
#   'ውሸት',
#   'አካል',
#   'መክሰስ',
#   'መረጃ',
#   'ውጥእ',
#   'አካል',
#   'ቢሮ',
#   'መዘገበ',
#   'አወቀ',
#   'ድርጅት'],
#  ['ኮሌኔል', 'አለበል', 'አማራ', 'ክልል', 'በራ', 'ሀይል', 'ስራ_አስፈጻሚ', 'ሾመ', 'ሾመ'],
#  ['እግዚአብሄር', 'ጠላት', 'ዛሬ', 'ሰማ', 'ድምጽ', 'መረጠ'],
#  ['ሞጣ',
#   'ፈጸመ',
#   'መስጊድ',
#   'ተቃጠለ',
#   'አስነዋሪ',
#   'ድርጊት',
#   'ጤነኛ',
#   'አወገዘ',
#   'ድርግ',
#   'ሞጣ',
#   'ሙስሊም',
#   'ወንድም',
#   'ጎን_ቆመ',
#   'ጥሪየን',
#   'ቀረበ',
#   'አማራ'],
#  ['ህይወት',
#   'አይነት',
#   'ደነዝ',
#   'አለም',
#   'ኖረ',
#   'ብየ',
#   'ፍጹም',
#   'ላመ',
#   'ግን',
#   'ኢትዮጵያዊ',
#   'ወከለ',
#   'እንዴውም',
#   'ለውጥ',
#   'አደናቃፊ',
#   'ግለሰብ'],
#  ['ላመ', 'ኧረ', 'ቅሌት'],
#  ['እባክሽ', 'ቻይንዬ', 'ብድር', 'ይቺ', 'ስልጠና', 'ብሄር_ብሄረሰብ', 'ስጭልን'],
#  ['ወገኛ',
#   'ድርግ',
#   'አየ',
#   'አይነት',
#   'መርዝ',
#   'ቦልኬ',
#   'ክብር',
#   'ሰጠ',
#   'ልክ',
#   'ስትቦልከኝ',
#   'ደንብ',
#   'እንዳስነቀልኩክ',
#   'ረገጠ',
#   'ነቀለ',
#   'ራስ',
#   'ግዜ',
#   'ስጠውበዚያውም',
#   'እርርቅጥል',
#   'አማራ',
#   'ለሁሉምአማራ',
#   'ሁሉምአማራለ',
#   'አማራ'],
#  ['ደራ',
#   'ደራ',
#   'አማራ',
#   'ሰራ',
#   'ኰሳ',
#   'ከጋ',
#   'ጦርነት',
#   'ምንፈልገው',
#   'ሸለለ',
#   'እየፎከሮ',
#   'ኦሮሞውን',
#   'ወጣ',
#   'ገባ',
#   'ሰጠ',
#   'ኦሮሞ',
#   'አቅጣጫ',
#   'ጦርነት'],
#  ['ብዙ',
#   'መብራት',
#   'ክፍያ',
#   'ተያያዘ',
#   'ቅሬታ',
#   'ሰማ',
#   'ታዝቤያለሁ',
#   'ተመለከተ',
#   'ሰራ',
#   'ቤት',
#   'ጠየቀ',
#   'አጥጋቢ',
#   'ምላሽ',
#   'ግኝ*',
#   'አገልግሎት',
#   'ቈረጠ',
#   'ጠየቀ',
#   'ከፈለ'],
#  ['እባካችሁ', 'መምህር', 'ስልክ', 'ሰጠ', 'ተገኘ'],
#  ['ደገመ'],
#  ['ተስፋ', 'ድርግ'],
#  ['ግድ',
#   'የበታችነት',
#   'ስሜት',
#   'ይስማ',
#   'ማንነት',
#   'የሚያቅ',
#   'ኩሩ',
#   'ኢትዮጵያዊ',
#   'አላህ',
#   'ረዳ',
#   'ደረሰ',
#   'በደል',
#   'ለቀቀ',
#   'ጠቀመ'],
#  ['መልካምነት',
#   'ከፈለ',
#   'ግን',
#   'ልጅ',
#   'ወቃ',
#   'ምሁር',
#   'ጋዜጠኛ',
#   'ተማሪ',
#   'ሀይማኖት',
#   'መሪ',
#   'መልካምነት',
#   'ከፈለ',
#   'ማንበብ',
#   'ሙሉ',
#   'ፍቅር',
#   'አሸ'],
#  ['ቁጠባ', 'ልምድ', 'መለዎወጫ'],
#  ['ሰላማዊት',
#   'ከተማ',
#   'መቐለ',
#   'ሄደ',
#   'አያካይድም',
#   'እስክንድር',
#   'አቅም',
#   'ጠዳ',
#   'ትግራይ',
#   'ተተራመሰ',
#   'ደስታ',
#   'ጸጉር',
#   'በቀለ'],
#  ['ቱርክ',
#   'ምክር_ቤት',
#   'ራቺብ',
#   'ጣይብ',
#   'ኤርዶኻን',
#   'ሊቢያ',
#   'ወታደር',
#   'ዘመተ',
#   'ቀረበ',
#   'ጥያቄ',
#   'ጸደቀ',
#   'ግብጽ',
#   'ጉዳይ',
#   'ሰራ',
#   'ቤት',
#   'ከተመ',
#   'ጸጥታ',
#   'ምክር_ቤት',
#   'ውሳኔ',
#   'ሀሳብ',
#   'ቀረ',
#   'ተቀባይነት',
#   'ምክር_ቤት',
#   'ውሳኔ',
#   'ተቃወመ'],
#  ['ኦሮሚያ',
#   'ክልል',
#   'ምእራብ_ወለጋ',
#   'ዞን',
#   'ጊዳሚ',
#   'ወረዳ',
#   'ደረሰ',
#   'መኪና_አደጋ',
#   'ሞት',
#   'ኤፍ',
#   'ቢ',
#   'ሲ'],
#  ['ሰላማዊ_ሰልፍ',
#   'ድርግ',
#   'ጉዳይ',
#   'ጊዜ',
#   'ሰጠ',
#   'አማራ',
#   'ታግተው',
#   'ችግር',
#   'አሉ',
#   'ወገን',
#   'ድምጽ',
#   'ሰማ',
#   'ሰአት',
#   'ዛሬ',
#   'አማራ',
#   'ደረሰ',
#   'ሞት',
#   'ስደት',
#   'ጠየቀ',
#   'አብይ_አህመድ',
#   'አወቀ'],
#  ['ህወሀትከፕሮፌሰር', 'መረራ', 'ሰራ', 'ፕር', 'መረራ', 'ከህወሀት', 'ሰራ', 'እለት', 'ወሬ', 'ድምጥ'],
#  ['ውነት', 'አፈረ', 'ክፍል', 'ተማሬ', 'ይሄን', 'አቀደ', 'አለመ', 'ሰካ', 'የእስፖንሰር', 'ድርቅ'],
#  ['ጥበብ', 'ቤተሰብ', 'ጠራ', 'እሰቃየችን', 'ከአብርሽ', 'ዝምድና'],
#  ['ጀግና', 'በፓለቲካ', 'ጫና', 'በቶሎ', 'ለቀቀ', 'ኖረ'],
#  ['በሙስልሙ',
#   'ህብረተሰብ',
#   'ጥላቻ',
#   'ታወረ',
#   'ፔጆችን',
#   'ብሎክ',
#   'ድርግ',
#   'ጊዜ',
#   '"አዲስ',
#   'አበቤ"በሚል',
#   'ጠራ',
#   'ፔጅ',
#   'ጀመረ',
#   'ሰማ'],
#  ['ይሄ', 'አየ', 'ግን', 'ተሻለ'],
#  ['አወቀ',
#   'ኬንያ',
#   'ቴሌቪዥን',
#   'ጣቢያ',
#   'ሲቲዝን',
#   'ቴቪ',
#   'ላም',
#   'ፕሮጀክት',
#   'ተሳካ',
#   'ቁርጠኘነት',
#   'ተከተለ',
#   'ዘገበ'],
#  ['ይሄን', 'አወቀ', 'ቤተክርስቲያን', 'አጥር', 'ስር', 'ጣለ', 'ላፈ'],
#  ['ነጣ', 'ውሸት', 'ቴሌቪዥን', 'ቀረበ', 'ውርእ', 'ድፍረት', 'መጣ'],
#  ['ሀገር',
#   'ሽማግሌ',
#   'ህግ',
#   'በላይነት',
#   'አገዘ',
#   'የስርአተአልበኞች',
#   'ተጠቃ',
#   'ሲሀኑ',
#   'አየ',
#   'አዛውንት',
#   'ወጠጤ',
#   'ጡጫ',
#   'እርግጫ',
#   'ለመደ',
#   'አየ',
#   'አመመ'],
#  ['ሊላው',
#   'ደጋ',
#   'ወልቃይት',
#   'ጠገዲ',
#   'ተነሳ',
#   'የካዛ',
#   'ወንዝ',
#   'አንገረብ',
#   'ገደበ',
#   'ቁልቁል',
#   'የወልቃይት',
#   'ጠገዲን',
#   'ሰሊጥ',
#   'ሰለቸ',
#   'መሪት',
#   'ለፍራፍሪ',
#   'ቆሎ',
#   'ልማት',
#   'ዋለ',
#   'ሀገር',
#   'ምግብ',
#   'ዋስትና',
#   'ምንዛሪ',
#   'ምንጭ',
#   'እላለው'],
#  ['እግዚአብሄር', 'ወደደ', 'አሳብ', 'ጠራ', 'በጎ', 'ተደረገ', 'አወቀ'],
#  ['ኤክሳይዝ_ታክስ',
#   'ጨመረ',
#   'ተሳሳተ',
#   'ምክንያት',
#   'አላስፈላጊ',
#   'ዋጋ',
#   'ጨመረ',
#   'ነጋዴ',
#   'እርምጃ_ወሰደ'],
#  ['ለፋ',
#   'ብሄራዊ',
#   'ቴአትር',
#   'አካባቢ',
#   'ግኝ*',
#   'ሸክም',
#   'ቀለለ',
#   'ተበላሸ',
#   'ቆመ',
#   'መኪና',
#   'ሰጠ',
#   'አበረታተነው',
#   'ዛሬ',
#   'አዲ',
#   'ተስፋ',
#   'ስራ',
#   'ጀመረ',
#   'ችግር',
#   'ተሻገረ',
#   'አየ',
#   'ደስ',
#   'ወደቀ',
#   'ቀረ'],
#  ['ሉቃስ',
#   'ማርያም',
#   'አለች—',
#   'ነፍስ',
#   'ጌታ',
#   'ከበረ',
#   'መንፈስ',
#   'አምላክ',
#   'መድሀኒት',
#   'ሀሴት',
#   'ድርግ',
#   'ባሪያ',
#   'ውርደት',
#   'ተመለከተ',
#   'እነሆም',
#   'ዛር',
#   'ትውልድ',
#   'ብጽእት'],
#  ['ገና', 'ፍሬ'],
#  ['ገና', 'ዛሬ', 'ትክክለኛ', 'ዜና', 'ቀረበ'],
#  ['ውነት', 'ኛ', 'ምትኖር', 'አያርገው'],
#  ['ረገጠ',
#   'ዜና',
#   'ምእራብ_ወለጋ',
#   'ሸመቀ',
#   'የሸኔኦነግ',
#   'ውግእ',
#   'ያህሉ',
#   'ሰራ',
#   'ፈቶ',
#   'እጅ',
#   'ሰጠ',
#   'ሰአት',
#   'ጫካ',
#   'ቀረ',
#   'ጥቂት',
#   'ውጥእ'],
#  ['እረ',
#   'ደገመ',
#   'እናገራለው',
#   'ማንቼ',
#   'ሰማ',
#   'አቁሞዋል',
#   'አይነት',
#   'ናደ',
#   'ናፈቀ',
#   'ከሊቨፑል',
#   'ምናረገውን'],
#  ['ጠቀለለ_ሚኒስትር',
#   'በሚሊኒየም',
#   'ደረሰ',
#   'ሴት',
#   'ሰበሰበ',
#   'ብልጽግና',
#   'የሚባሀው',
#   'ፓርቲ',
#   'ሴት',
#   'ለማበልጸግ',
#   'ሰራ',
#   'በሚምሉበተሰ',
#   'ከአት',
#   'ሴት',
#   'ተማረ',
#   'ኦሮሞ',
#   'ጽንፈኛ',
#   'ጠለፈ',
#   'ገፋ',
#   'ሰራ',
#   'ተገኘ'],
#  ['ጥበብ'],
#  ['ደገመ', 'ቶሎ', 'ተከፋ', 'ጸባይ', 'ተሻሻለ'],
#  ['አለፈ',
#   'አመት',
#   'መላ',
#   'ሀገር',
#   'መስጊድ',
#   'ቀጠለ',
#   'አወቀ',
#   'ቱ',
#   'ቀጠለ',
#   'መስጊድ',
#   'ቀጠለ',
#   'ክልል',
#   'አማራ',
#   'ብሄራዊ',
#   'ክልል'],
#  ['“ህወሀት',
#   'ብልጽግና',
#   'ፓርቲ',
#   'ተዋህዳ',
#   'ከሰመ',
#   'ኖረ',
#   'ትግራይ',
#   'መሪ',
#   'ድርጅት',
#   'አረና',
#   'ዶ',
#   'በለ',
#   'አማረ',
#   'ቀረረ'],
#  ['ደገመ', 'ይፋ', 'አብይ', 'ዛፍ', 'ቈረጠ', 'የምናየዉ'],
#  ['ይሄም', 'ገብረ', 'ክርስቶስ', 'ደስታ', 'ልዮ', 'ግጥም', 'ግዜ', 'ገነነ', 'አየ'],
#  ['አሜን', 'ሰላም', 'ብሩ', 'ሳምንት'],
#  ['እውነት',
#   'ተናገረ',
#   'ለመደ',
#   'አይነት',
#   'ተቃዋሚ',
#   'ፓርቲ',
#   'ለየ',
#   'ጤነኛ',
#   'ፓርቲ',
#   'መረጠ',
#   'አሰበ',
#   'ገባ'],
#  ['ነገረኛ'],
#  ['ቢኒ', 'ደንበኝነቴን', 'ለማጽናት', 'ቃል', 'ገባ'],
#  ['ፈቀደ',
#   'ውይ*',
#   'ቢሊዮን',
#   'ቈጠረ',
#   'መሬት',
#   'ገንዘብ',
#   'ዘረፈ',
#   'ፎቶ',
#   'ሰበሰበ',
#   'ገንዘብ',
#   'ፈቀደ',
#   'ምርጫ',
#   'ምርጫ',
#   'ቁሳቁስ',
#   'ገዛ',
#   'ጣረ',
#   'ጉቶ'],
#  ['እንኬው', 'ክንደብርቱ', 'በርታ', 'ተሸነፈ', 'እርግጠኛ'],
#  ['“እነሆ',
#   'ታላቅ',
#   'ደስታ_ምስራች',
#   'ነገረ',
#   'ፈራ',
#   'ዛሬ',
#   'ዳዊት',
#   'ከተማ',
#   'መድሀኒት',
#   'እርስ',
#   'ክርስቶስ',
#   'ጌታ',
#   'ተወልዶላችኋልና”',
#   'ብርሀነ_ልደት',
#   'ደረሰ',
#   'የእየሱስ',
#   'ክርስቶስ',
#   'ፍቅር',
#   'በረከት',
#   'በሁላችን',
#   'አደረ'],
#  ['ቀሽም', 'እረ', 'ኖረ', 'ሞተ'],
#  ['መንግስት', 'ወንጌል', 'አለም_ቀፈፈ', 'ቤተክርስቲያን', 'ወጣት', 'ዝማሬ'],
#  ['"ምናልባት',
#   'ይሄ',
#   'ዛሬ',
#   'ይፋ',
#   'ድርግ',
#   'ስጦታ',
#   'ተያያዘ',
#   'ጠየቀ',
#   'ተገኛኘ',
#   'ኢንተርኔት',
#   'ጽሁፍ',
#   'መልእክት',
#   'አገልግሎት',
#   'ሰራ',
#   'ነበር"'],
#  ['"የኢትዮጵያ',
#   'ኤምባሲ',
#   'ዋሽንግተን',
#   'ታላቅ',
#   'ሙዚቃ',
#   'ድግ',
#   '"',
#   'ናስ',
#   'ታጋቾቹ',
#   'ለቀቀ',
#   'አከለ'],
#  ['ችግር', 'ተከለ', 'ተቻለ', 'ብሄር', 'ራስ', 'ፓርቲ', 'ይፍጠር'],
#  ['መሰለ',
#   'የበታች',
#   'ቀረ',
#   'ነዋ',
#   'አገር',
#   'ወዳድ',
#   'ልማት',
#   'አንድነት',
#   'ስኬት',
#   'ተጋ',
#   'ሰራ',
#   'ቻለ'],
#  ['እሺ', 'ህን', 'ቀየረ', 'አስራት', 'ወልደየስ', 'አማራ', 'ጎጠኛ'],
#  ['ካስየ',
#   'አማራ',
#   'አምሳለ',
#   'ፈጠረ',
#   'አማራ',
#   'ፍትህ',
#   'ጐደለ',
#   'ብየህ',
#   'ፍርድ',
#   'በቅሎየን',
#   'ወሰደ',
#   'ፍርድ',
#   'ጭብጦየን',
#   'ቀማ',
#   'ቈጨ',
#   'ባይ',
#   'ይሄው'],
#  ['ነባ',
#   'ነባ',
#   'በለጠ',
#   'አሉ',
#   'አማርኛ',
#   'ተረጐመ',
#   'ቀጠለ',
#   'ጥቂት',
#   'በራ',
#   'አራት',
#   'እጥፍ',
#   'ከፈለ',
#   'ጀመረ',
#   'አስቻለ',
#   'ይ'],
#  ['ህገ', 'ወጥ', 'ታዲያ', 'ለመደ', 'ሰበሰበ', 'አሰረ', 'ብልጽግና', 'ፖርቲ', 'አባል'],
#  ['ሀገር',
#   'ውጥንቅጥ',
#   'ፖለቲካ',
#   'ዜጋ_ደህንነት',
#   'እጦት',
#   'ተገኘ',
#   'አንገብጋቢ',
#   'ችግር',
#   'ምክር_ቤት',
#   'ሎጎ',
#   'ምርጫ',
#   'ኖረ',
#   'ላከ',
#   'ሳተላይት',
#   'አበረ',
#   'መጥቀዋል',
#   'መሰለ'],
#  ['አሪፍ', 'ግን', 'አረም', 'ጥቅም', 'ቀየረ', 'ቻለ', 'ጥናት', 'ውድ', 'አብኖች'],
#  ['እንዴ',
#   'ገረመ',
#   'እንዴ',
#   'በረረ',
#   'ላከ',
#   'ያንጫጫቹሃል',
#   'ደግ',
#   'አረገ',
#   'አደገ',
#   'ዘመን',
#   'እንዴህ',
#   'ሰላጣ',
#   'ዳኳ',
#   'ጨመረ',
#   'ደንብ',
#   'በላ'],
#  ['ሀሳብ',
#   'ያዘ',
#   'ለም',
#   'ቀጠለ',
#   'እስክንድር',
#   'ትንሽ',
#   'ትልቅ',
#   'የምታብጠለጥሉት',
#   'ቀልዳቹሁ',
#   'እንጨት',
#   'እንጨት',
#   'ተነሳ',
#   'አፎን',
#   'ከፈተ',
#   'ዝም',
#   'አለለ',
#   'የኢዜማ',
#   'ጥርቅም',
#   'ተናገረ',
#   'ገባ',
#   'ቋንቋ',
#   'መለሰ'],
#  ['ደሞ', 'ውዱእ', 'ቀረ', 'ኡዱ', 'ጠመመ'],
#  ['ሃሃሃሃ', 'ዶማነትህ', 'ጀመረ', 'ውነት', 'መሰለ', 'ወሸት', 'ዋሸ', 'ውሸት', 'ማስረጃ', 'ቀረበ'],
#  ['ሆይ',
#   'መልካም',
#   'አየ',
#   'እግዚአብሄር',
#   'ፈለገ',
#   'ፍትህ',
#   'ድርግ',
#   'ምህረት',
#   'ትወድድ',
#   'አምላክ',
#   'ፊት',
#   'ትህትና',
#   'ተራመደ',
#   'አይደለምን',
#   'ሚክያስ'],
#  ['አትመርቅን', 'እኮ', 'ሽንት', 'ወጠረ', 'ራስ', '"ምን', 'ላድርግ"', 'መከረ', 'እኮ'],
#  ['ጀመረ',
#   'ትምህርት_ሚኒስቴር',
#   'ስርነቀል',
#   'ተቋማዊ',
#   'ለውጥ',
#   'ተካሄደ',
#   'ተሻለ',
#   'እውቀት',
#   'ምግባር',
#   'ችግር',
#   'ተማረ',
#   'ትውልድ',
#   'አፈራ',
#   'ተቋም',
#   'ለወጠ',
#   'አዲስ',
#   'ስርአተ_ትምህርት',
#   'ቀረጸ',
#   'ገበረ',
#   'ለውጥ',
#   'ኖረ'],
#  ['ጭራቅ',
#   'ታታ',
#   'በአርቴፊሻል',
#   'ብትሽሞኘሙኝም',
#   'ወረደ',
#   'ጀመረ',
#   'ራስ',
#   'ኩሪ',
#   'ፈሳ',
#   'ከፈተ',
#   'ፊት',
#   'ጨ',
#   'ገለበጠ'],
#  ['ሙስሊም',
#   'ጠላት',
#   'ከየ',
#   'አቅጣጫ',
#   'በዛ',
#   'እርስ_እርስ',
#   'አንድነት',
#   'በለጠ',
#   'ይጠናክራል',
#   'ጠላት',
#   'ጋራ',
#   'ዲል',
#   'ያድርጋሉ'],
#  ['ደነቀ',
#   'ንጉስ',
#   'ሁላችንም',
#   'ትልቅ',
#   'ቤተሰብ',
#   'እግዚአብሄር',
#   'ልጅ',
#   'ኖረ',
#   'እውስ',
#   'ዛሬ',
#   'ልዩ',
#   'ምሽት'],
#  ['"የኔ',
#   'ውሻ',
#   'ኪሎ',
#   'ፊክሪ"',
#   'ወለደ',
#   'ልጅ',
#   'እናት',
#   'ውሻ',
#   'እለት',
#   'ጣለ',
#   'ሰበብ',
#   'አጣ',
#   'በቁንጥጫ',
#   'ለምዝጌ',
#   'ማር',
#   'ቢሮ',
#   'እየቆስኩት',
#   'ያሁነያ'],
#  ['አዲሰ', 'አበባ', 'ሞጣ', 'መሰለ', 'እንዴ'],
#  ['ግድብ',
#   'ግንባታ',
#   'ጀመረ',
#   'ጀመሮ',
#   'ተሳካ',
#   'እርስ_እርስ',
#   'ድርድር',
#   'ሸመገለ',
#   'ሰካ',
#   'በአለማቀፍ',
#   'ፍርድቤት',
#   'ዳኘ',
#   'ቻለ',
#   'ጉዳይ',
#   'ደነበረ',
#   'ለማ',
#   'ግልጽ',
#   'ጀመረ',
#   'መረጠ',
#   'አለተሳካም',
#   'ሁለትኛው',
#   'መረጠ',
#   'አለነ'],
#  ['ሴት', 'ባረከ', 'ማህጸን', 'ፍሬ', 'ባረከ', 'ጸጋ', 'ተመላሽ', 'ድንግል', 'ሆይ', 'ደስ'],
#  ['ፈተነ', 'አለፈ', 'ከበደ', 'ከበደ', 'መስዋእት', 'ምድር', 'ከፍታ', 'ወረደ', '→←'],
#  ['ዶር_አብይ_አህመድ', 'ኦሮሞ', 'አማራ', 'ገደለ', 'ስልጣን', 'መጣ', 'ቆሻሻ', 'ተግባር', 'ነዉ'],
#  ['“ጦርነት',
#   'ወደደ',
#   'እገዛ',
#   'ውሀ',
#   'ጥገኛ',
#   'የሚያድርግ',
#   'ውል',
#   'ተቀበለ',
#   'ጦርነት',
#   'እንመርጣለን”',
#   'ግን',
#   'ደገመ',
#   '“ለውጡ“',
#   'ተደናቀፈ',
#   'ይሆን¡'],
#  ['ቍጥር', 'ሰላ', '"እሱ', 'ሰጠኝ', 'ጸጋ"'],
#  ['ወላሂ', 'ቀረ', 'ካርድ', 'ቃል', 'ገባ', 'እባክዎትን', 'ቁጥሩዎን', 'ለካ'],
#  ['ሀገራዊ',
#   'የሳይበር',
#   'ደህንነት',
#   'ዙሪያ',
#   'ቆመ',
#   'ኮሚቴ',
#   'አባል',
#   'ስልጠና',
#   'ሰጠ',
#   'ሀዋሳ',
#   'ታህሳስ',
#   'አመመ',
#   'ደሬቴድ',
#   'ሀገራዊ',
#   'የሳይበር',
#   'ደህንነት',
#   'ዙሪያ',
#   'ወከለ_ምክር',
#   'ቤት',
#   'ግንኙነት',
#   'ሰላም',
#   'ጉዳይ',
#   'ቋሚ_ኮሚቴ',
#   'አባል',
#   'ስልጠና',
#   'ሰጠ'],
#  ['ብዙ',
#   'መረረ',
#   'ደላላ',
#   'ስስ',
#   'ተጭዋውተናል',
#   'ጠየቀ',
#   'ጠቀመ',
#   'ጠቈመ',
#   'አማረ',
#   'መስፍ',
#   'ወንድወሰን',
#   'ግጥም',
#   'ደቂቃ',
#   'አበረ',
#   'ተጫወተ',
#   'ወደደ',
#   'ጋበዘ'],
#  ['ትግራይ',
#   'ክልል',
#   'አክሱም',
#   'ከተማ',
#   'አማራ',
#   'ክልል',
#   'እስልምና',
#   'እምነት_ተከታይ',
#   'መስገጃ',
#   'ቦታ',
#   'እጦት',
#   'ትውልድ',
#   'ቀዬው',
#   'ቀበረ',
#   'ቻለ',
#   'ችግር',
#   'ምክር_ቤት',
#   'ገለጸ',
#   'አትቷል'],
#  [],
#  ['ወዮ', 'ይቺ', 'ደገመ', 'ባሰ'],
#  ['አቤት', 'መከረ', 'ብዛት', 'ምክር', 'አይነት', 'ገረመ', 'ጥር'],
#  ['"የኢትዮኤርትራ',
#   'ሰላም',
#   'ጉዳይ',
#   'ጠማ',
#   'ሀማርያም',
#   'ደሳለኝ',
#   'ስልጣን',
#   'ዘመን',
#   'ጀመረ',
#   'የኢህኣዴግ',
#   'ሰላም',
#   'ቅድ',
#   'የኣብዪ',
#   'አህመድ',
#   'ሰላም',
#   'ፕሮጄክት',
#   'እርግጥ',
#   'በላ',
#   'ኣቀላጥፈውታል'],
#  ['ማንነት', 'ግልጽ', 'ይፋ', 'ተደረገ'],
#  ['አይ',
#   'ሸገር',
#   'አይ',
#   'አዱ',
#   'ገነት',
#   'ከተማ',
#   'ታክሲ',
#   'ብር',
#   'መንገድ',
#   'ልዩነት',
#   'ክርስትና',
#   'ልጅ',
#   'እንጀራ',
#   'ልጅ',
#   'ካዛ',
#   'ከፈለ',
#   'ስብሰባ',
#   'ደረሰ',
#   'ከለከለ',
#   'ደሞ',
#   'ቦሌ',
#   'ደገመ',
#   'ገና',
#   'ከፈለ',
#   'ጨፈረ'],
#  ['አይ', 'ወያኔ', 'እውስ'],
#  ['ብር',
#   'ጉዳይ',
#   'ረጋ',
#   'ሀገር',
#   'ሰላም',
#   'ብልጽግና',
#   'መጣ',
#   'ከአይዲዮሎጂ',
#   'አንጻር',
#   'ተመለከተ',
#   'አጀንዳ',
#   'ድርድር',
#   'ወረደ',
#   'አውድ',
#   'ፈጸመ',
#   'ተሸነፈ',
#   'ጫነ',
#   'ፍላጎት',
#   'አየ'],
#  ['ኢሳ',
#   'ፊት',
#   'ቡቃያ',
#   'ደረቅ',
#   'መሬት',
#   'ስር',
#   'አደገ',
#   'መልክ',
#   'ውበት',
#   'አየነው',
#   'ጊዜ',
#   'እንወድደው',
#   'ደም',
#   'ገባ',
#   'ናቀ',
#   'ጠላ',
#   'ህማም',
#   'ደዌ',
#   'አወቀ',
#   'ፊት',
#   'ሰወረ',
#   'ናቀ'],
#  ['ቢሊሱማ',
#   'አባት',
#   'ኦነግ',
#   'ስራ',
#   'ብርር',
#   'አሰረ',
#   'ወጥ',
#   'እናት',
#   'ኑሮ',
#   'ጫና',
#   'ምክንያት',
#   'ጥላ',
#   'ጠፋ',
#   'አዲስ_አበባ',
#   'ሰማ',
#   'ጋራ',
#   'ፈለገ',
#   'ከርመናል'],
#  ['ጨረሰ',
#   'እስትንፋሳ',
#   'ድርግ',
#   'ድረስ',
#   'ከፍተኛ',
#   'ስቃይ',
#   'ሰማ',
#   'ደም',
#   'መስመር',
#   'ተሰቃየ',
#   'አመመ',
#   'ሞተ',
#   'ሲኦል',
#   'ዋሻ',
#   'ሰራ',
#   'ሀጢአት',
#   'እራስዎን',
#   'ለማዳ',
#   'ቻለ',
#   'ለም'],
#  ['ሟርተኛ', 'አቶ', 'ያሬድ', 'ገና', 'ከበረ', 'mWርት'],
#  ['ኢዜማና',
#   'ብልጽግና',
#   'ብዙ',
#   'መሰለ',
#   'ሽግግር',
#   'ቅድሚያ',
#   'ተጫወተ',
#   'ሜዳ',
#   'መስተካከል',
#   'ሰጠ',
#   'ስልጣን',
#   'ደም_ፈሰሰ',
#   'ግጭት',
#   'ቀሰቀሰ',
#   'ቀሰረ',
#   'አተካሮዎች',
#   'ገባ'],
#  ['እሺ', 'ሚስት', 'ጠበቃ'],
#  ['ገባ', 'ገባ', 'ይምስለኛል'],
#  ['"ገነትና',
#   'ሲኦል',
#   'ኖረ',
#   'ኖረ',
#   'አክልለማሪያም',
#   'ደግ',
#   'ሰረቶ',
#   'አለፈ',
#   'ተሻለ',
#   'ቀረረ',
#   '"'],
#  ['አረ', 'ፍቅር', 'ፍቅር'],
#  ['ዳር',
#   'ቆመ',
#   'ሀሳብ',
#   'ከነእንከን',
#   'ከማሞካሸት',
#   'ተቸ',
#   'መሀል',
#   'ቆመ',
#   'ውእል',
#   'መረመረ',
#   'መዘነ',
#   'አሳማኝ',
#   'ሀሳብ',
#   'ወሰደ',
#   'ወደመ',
#   'ደገመ',
#   'ተወ',
#   'ፊት',
#   'ሄደ',
#   'ብልህ'],
#  ['ኢዜማ',
#   'የገዥዉ',
#   'ፓርቲ',
#   'ቲፎዞ',
#   'አስፈለገዉ',
#   'ገዥ',
#   'ፓርቲ',
#   'ደገፈ',
#   'ተቃዋሚ',
#   'ተወዳደረ',
#   'ብቸኛ',
#   'ፓርቲ',
#   'ነዉ',
#   'ብልጽግና',
#   'ፓርቲ',
#   'ገና',
#   'ስልጣን',
#   'ያዘ',
#   'እነ',
#   'ጠላ',
#   'የሚዉል',
#   'ፓርቲ',
#   'ነዉ',
#   'ኢዜማ'],
#  ['ኦሮሞ',
#   'ብሄር_ብሄረሰብ',
#   'ተከባበረ',
#   'እራሱን',
#   'ራስ',
#   'ተዳደረ',
#   'መልካም',
#   'አስተዳደር',
#   'ችግር',
#   'ተፈቶለት',
#   'ለማ',
#   'ኦዲፒ',
#   'መለሰ',
#   'ጥያቄ'],
#  ['እውነት', '"አንተን', 'ጨቈነ', '"አልተጨቆንኩም"', 'አመነ', 'ድረስ', 'ነው"'],
#  ['አመመ', 'ሳይንስ', 'ዝግጅት', 'ቅኝት', 'በከፊል'],
#  ['አበረ', 'አማራ', 'በጎ_አድራጎት', 'ድርጅት', 'መሰረተ'],
#  ['እንጀራ',
#   'ህልም',
#   'አየ',
#   'ሆድ',
#   'ተሰኘ',
#   'ሲበሎ',
#   'አየ',
#   'በዩቱብ',
#   'በፌስ',
#   'ቡክ',
#   'መንደር',
#   'እቃ',
#   'ብዙ',
#   'አመት',
#   'ቈጠረ',
#   'እንጀራየ'],
#  ['"ከ',
#   'አመት',
#   'ፊት',
#   'ትልቅ',
#   'ፈተና',
#   'ገጠመ',
#   'ትንሽ',
#   'ጠንከር',
#   'ፈተና',
#   'ገጠሞናል',
#   'ጋረጠ',
#   'ፈተና',
#   'ውጥእ',
#   'ትውልድ',
#   'ሀላፊነት',
#   'ነው"',
#   'ብጀነራል',
#   'አሳምነው_ጽጌ'],
#  ['ውነት',
#   'ተናገረ',
#   'ፖለቲካ',
#   'አሰበ',
#   'ተባበረ',
#   'ሀገር',
#   'ዘመናዊ',
#   'ቅኝ',
#   'ገዛ',
#   'አደገ',
#   'ሀገር',
#   'ስል',
#   'አሮጊት',
#   'ሴትዮ',
#   'ራስ'],
#  ['ለእየሱስ',
#   'ባሪያ',
#   'የኢብኑል',
#   'ቀይ',
#   'አልጀውዚያህ',
#   'ድንቅ',
#   'ግጥም',
#   'ግርድፍ',
#   'ትርጉም',
#   'በኢብኑ',
#   'ሙነወር'],
#  ['የእግዚያብሄር',
#   'ትግስት',
#   'ሞላ',
#   'ፈሰሰ',
#   'ወዳጅ',
#   'ግብረ',
#   'ሶዶምን',
#   'ጋብቻ',
#   'ጸደቀ',
#   'መባቻ',
#   'ፈጠረ'],
#  [],
#  ['አማረ', 'ጎበዝ'],
#  ['እርቀቱን',
#   'ረዳ',
#   'ልደት',
#   'አየ',
#   'ጽንሰቱም',
#   'ልደት',
#   'ፍጹም',
#   'ድንግል',
#   'መቃብር',
#   'ወረደ',
#   'ተነሳ',
#   'ድንጋይ',
#   'አስነስቶ',
#   'ገነዘ',
#   'ፈታ',
#   'አደለ',
#   'አሸገ',
#   'መቃብር',
#   'ወጣ',
#   'ይሄም',
#   'መለኮተ',
#   'ረቂቅ'],
#  ['ነባር',
#   'ስርአተ_ትምህርት',
#   'አመመ',
#   'ሙሉ',
#   'ሙሉ',
#   'አዲ',
#   'ስርአተትምህርት',
#   'ተካ',
#   'ገለጸ',
#   'ስራ',
#   'አመት',
#   'ጥንቅቅ',
#   'ተሰራ',
#   'ትምህርት_ሚኒስቴር',
#   'ተገኘ',
#   'መረጃ',
#   'ተመለከተ'],
#  ['አማረቸዎች', 'ምነዉ', 'ተኛ', 'ጀዋር', 'መራ', 'ደፋ', 'ቀና', 'ነዉ', 'ምርጫ', 'ጸሎት', 'ለአቢቹ'],
#  ['ሰላም', 'አገር', 'ልጅ', 'እስኪ', 'ሁላችንም', 'አመነ', 'እምነት', 'አገር', 'ሰላም', 'ጸለየ'],
#  ['የቧንቧ', 'ስራ', 'የሚሰራሎት', 'ሰራተኛ', 'ፈለግ', 'ደወለ', 'ትዛዞን', 'ተቀበለ', 'ዝግጅ'],
#  ['መልካእረኛበጎቹንያበለጽጋልእንጂበበጎቹአይበለጽግም',
#   'ብጹእ',
#   'አባት',
#   'አቡነ',
#   'ይስሀቅ',
#   'በረከት',
#   'ደረሰ'],
#  ['ፕሮፌሰር',
#   'ኢሊችን',
#   'አመት',
#   'በጎ',
#   'ሸለመ',
#   'ቅቤ',
#   'ጠጣ',
#   'አሰበ',
#   'ሳተ',
#   'ተመቸ',
#   'መርዝ',
#   'በጠበጠ',
#   'ጠጣ',
#   'አይሁድ',
#   'ፕሮፌሰር',
#   'እውቅ_ሰጠ',
#   'ሸለመ',
#   'ሙስሊም',
#   'ቁስል',
#   'እንጨት',
#   'ሰደደ',
#   'አነሰ'],
#  ['አውስትራሊያ',
#   'ከሰተ',
#   'ሰአት',
#   'ተጠረጠረ',
#   'ክስ_መሰረተ',
#   'ኒው',
#   'ሳውዝ',
#   'ዌልስ',
#   'ግዛት',
#   'አደጋ',
#   'ዋነኛ',
#   'ተጠቃ',
#   'ግማሽ',
#   'ቢሊዮን',
#   'ተጠጋ',
#   'እንስሳ',
#   'ህይወት',
#   'አጥተ'],
#  ['ወረኛ'],
#  ['ብሎክ', 'ማድርግ', 'ተሸነፈ', 'ለማንኛው', 'ናይ', 'ናይ', 'ጤና', 'አዳም', 'ዘፈን', 'ዳመጠ'],
#  ['ሄኖክ', 'ድንቁ', 'ጀመረ', 'ካልሲ', 'አረገ', 'የሰይፋ', 'እንግዳ', 'መሰገ', 'ገባ'],
#  ['ከሀላ', 'ቀረ', 'ፈራ', 'ዝም', 'ቀላቀለ'],
#  ['ማለ', 'ኢትዩጵያ', 'መቸ', 'ሰላም', 'ሚኖራት'],
#  ['ልደት', 'ዛሬ', 'ወፍ', 'ነገረ', 'ገና', 'ማለዳ', 'ዘመረ', 'ሆሆሆ', 'ሄሄሄ', 'መልካም', 'ልደት'],
#  ['አዲስ_አበባ', 'ዩኒቨርሲቲ', 'አራት', 'መምህር', 'የፕሮፌሰርነት', 'ማእረግ', 'ሰጠ'],
#  ['ተልባ', 'ፈለገ', 'ማንቼ', 'ደገፈ', 'ረዳ', 'ቻለ'],
#  ['አለበለዚያ',
#   'አዲስ',
#   'ወያኔ',
#   'ሰራ',
#   'ዘጠኝ',
#   'ክልል',
#   'ዘጠና',
#   'ክልል',
#   'ሰራ',
#   'ባህር',
#   'ሲንድሮም',
#   'ለቀቀ'],
#  ['መንበረ', 'አክሊሉ', 'ጀግኒት', 'እግዚያብሄር', 'እድሜ_ጤና', 'በዛ', 'ሰጠ'],
#  ['ትራፊክ', 'ጉቦ', 'ተቀበለ', 'እዝላልነት', 'በሹፌሮች', 'አበበ', 'ተገቢ'],
#  ['እቺናት',
#   'ንግድ',
#   'ሀገር',
#   'ከህውሃት',
#   'አበረ',
#   'ሃገሪቷን',
#   'ወደብ',
#   'አለበ',
#   'ያስደረጉ',
#   'ቀጠለ',
# ...
#  ['እግዚአብሄር', 'ነብሳቸውን', 'ማረረ', 'ቤተሰብ', 'አጽናና'],
#  ['መቀሌ',
#   'ሰቀቀ',
#   'እስርቤት',
#   'ዉስጥ',
#   'አመት',
#   'ብረት',
#   'አሰረ',
#   'ማቀቀ',
#   'ኖረ',
#   'ሊቁ',
#   'መምህር',
#   'እስር',
#   'አግማሴ',
#   'ጉዳይ',
#   'ግን',
#   'የተ',
#   'ደረሰ',
#   'ጫጫታ',
#   'ቀረ',
#   'ታላቅ',
#   'የቤን',
#   'ሊቅ',
#   'ፈታ',
#   'ልኡል',
#   'እር',
#   'ጠየቀ'],
#  ['ሱስ',
#   'አለበ',
#   'ብልጽግና',
#   'ፓርቲ',
#   'ከኢህአዴግ',
#   'ቀይ',
#   'ወንበር',
#   'ሰማያዊ',
#   'ተሻገረ',
#   'ሁልጊዜም',
#   'አቀማመጥ',
#   'ዝብርቅርቅነት',
#   'ገረመ'],
#  ['አህመዲን_ጀበል', 'እምነት', 'የኦነግ', 'ስራ_አስፈጻሚ'],
#  ['መልካምነትህን',
#   'ደነቀ',
#   'ግን',
#   'ክቡር_ጠቀለለ',
#   'ሚኒስትር',
#   'ቅድሚያ',
#   'ሰጠ',
#   'ስጥ',
#   'ተራ',
#   'ዜጋ',
#   'ድርግ',
#   'ሀገር',
#   'ሰላም',
#   'ጸጥታ',
#   'ከበረ',
#   'ሀገር',
#   'አየ',
#   'ህገወጥንትን',
#   'አድሎአዊነትን',
#   'ተወገደ'],
#  ['አንቺማ',
#   'ጥር',
#   'ሊንኩን',
#   'አስቀምጠሽላቸዋልማየታቸውን',
#   'ተጠረጠረ',
#   'ታግ',
#   'ድርግ',
#   'ቢቢሲ',
#   'እኮ',
#   'ዜና',
#   'ሰራ'],
#  ['ውነት', 'ኤርትራ', 'ነጻ', 'ወጧል', 'ነጻ', 'ወጣ'],
#  ['ተመሰገነ', 'ፈጠረ', 'ታታ'],
#  ['ሴራ',
#   'በተነ',
#   'ተኰላሸ',
#   'መጣ',
#   'ኢሳት',
#   'አራተኛ',
#   'መንግስት',
#   'ተስፋ',
#   'ድርግ',
#   'ተቋም',
#   'አሽመድምዳችሁ',
#   'ቁጭ',
#   'ድርግ'],
#  ['በጥባጭ',
#   'ሀሳብ',
#   'ልእልና',
#   'አመነ',
#   'ወጠጤ',
#   'ሰም',
#   'ደቡብ',
#   'ምስራቅ',
#   'ምእራብ',
#   'ዲሞክራሲ',
#   'ጅምር',
#   'ጠላት',
#   'ነዉና',
#   'መወገዝ',
#   'አለበትኢትዮጵያዊነት',
#   'ጉልበት'],
#  ['"ነጻ"', 'ላላ', 'ሳቅ', 'ነጻ', 'ገለልተኛ', 'ጋዜጠኛ', 'ለም', 'ወገንተኛ'],
#  ['መጠጥ', 'እኮ', 'ሁለገብ', 'ከናንተጋር', 'ሀሪፍ', 'ቡና'],
#  ['ቀደም',
#   'ነበረ',
#   'ዋጀ',
#   'ኤክሳይዝ_ታክስ',
#   'ከፈለ',
#   'ነበረ',
#   'ልብስ',
#   'አጠበ',
#   'ማሽን',
#   'ተሻሻለ',
#   'ረቂቅ_ዋጀ',
#   'ከኤክሳይዝ',
#   'ታክስ',
#   'ነጻ',
#   'ተደረገ',
#   'ተባለ'],
#  ['ውነት', 'ናቲዬ', 'አማራ', 'ክልል', 'ቦታ', 'አሰብኩትኮ', 'ቈሸሸ'],
#  ['ጥር', 'ሀሳብ'],
#  ['እጅ',
#   'እግዚሄር',
#   'ለመነ',
#   'መሰለ',
#   'ድረስ',
#   'ማረከ',
#   'ኣልተሽንፍንም',
#   'አፍ',
#   'ቀደደ',
#   'ውርእ',
#   'ቀድሞ',
#   'ፈርጣጭ',
#   'ወተሃደር',
#   'ደርግ',
#   'ሀቅ',
#   'መሰከረ',
#   'ተባለ',
#   '"ለባም',
#   'ጽዉእ',
#   'ሸያብ',
#   'ኣይትጸዉእ"',
#   'አገር',
#   'ተረተ'],
#  ['ሞት', 'መጣ', 'ሰአት'],
#  ['አዲስ_አበባ',
#   'ባለአደራ',
#   'ምክር_ቤት',
#   'ሰብሳቢ',
#   'እስክንድር_ነጋ',
#   'ጥር',
#   'በኢንተር',
#   'ኮንቲኔንታል',
#   'ሆቴል',
#   'በር',
#   'ሰጠ',
#   'ጋዜጣዊ_መግለጫ',
#   'በከፊል'],
#  ['እራስን',
#   'ድል',
#   'ራስ',
#   'ወሰነ',
#   'መብት',
#   'ጀመረ',
#   'ግለሰብ',
#   'ቡድን',
#   'ሰጠ',
#   'መብት',
#   'ቅድም',
#   'ኢዜማ',
#   'ፌዴራል',
#   'ወቀረ',
#   'ሀሳብ',
#   'አንብያለሁ',
#   'አይደል',
#   'ደገመ',
#   'ሙሉ',
#   'መልስ',
#   'እዛ',
#   'ግኝ*'],
#  ['እስልምና_ጉዳይ',
#   'ጠቀለለ',
#   'ምክር_ቤት',
#   'ተሰማ',
#   'ቅሬታ',
#   'የሞጣውን',
#   'ጥቃት',
#   'ሪፖርት',
#   'ይፋ',
#   'ሙሉ',
#   'ገለጠ',
#   'ምስል',
#   'ጫነ',
#   'ተመለከተ'],
#  ['ትናንት',
#   'ሴት',
#   'አጃ',
#   'ሻይ',
#   'ቡና',
#   'ጨዋታ',
#   'ወቅታዊ',
#   'ፖለቲካ',
#   'ትኩሳት',
#   'ወሰደ',
#   'መረቅ',
#   'ትንተና',
#   'ሰማ',
#   'በምክንያትበመረጃበማስረጃ',
#   'ሴት',
#   'ፊት',
#   'መጠጠ',
#   'ፈጠረ',
#   'ጊዜ',
#   'ብልሀት',
#   'ተሻገረ'],
#  ['ሱሬ',
#   'ፕሮግራም',
#   'ተከታትየዋለሁ',
#   'አበለ',
#   'ተሰኘ',
#   'ነገርግን',
#   'ከዚ',
#   'ብዙ',
#   'ሀሳብ',
#   'አነሳ',
#   'ብይ',
#   'ገመተ',
#   'ጥር',
#   'ጅምር',
#   'በረታ'],
#  ['ሸፍጥ', 'በዛ', 'ባሉካው', 'ደረሰ', 'መለሰ'],
#  ['ኑዛዜ', '"አባቴ', 'መለስ_ዜናዊ', 'ጎን', 'ቅበሩኝ"', 'ውነት', 'አቸነፈ'],
#  ['ሙዚቃ',
#   'ርቀት',
#   'መጠነ',
#   'አሰበ',
#   'ደከመ',
#   'ብሄር',
#   'ቅመም',
#   'ጨመረ',
#   'ታታሪ',
#   'ለም',
#   'ውርጋጥ',
#   'ግለሰብ',
#   'ነፍ'],
#  ['አረ', 'ተወ', 'እስክንድር', 'እንደዛ', 'ለም', 'ምናልባት', 'ሳተ', 'መንገድ', 'ተረድተኸው'],
#  ['ልደት', 'ፖለቲካ', 'ጥንቅቅ', 'ድርግ', 'የሚያዉቅ', 'እዉነተኛ', 'ነዋ'],
#  ['አብይ',
#   'ትራምፕ',
#   'ተስማማ',
#   'አገር',
#   'አዳነ',
#   'ምስጢርማ',
#   'ትራምፕ',
#   'ትናንት',
#   'ተናገረ',
#   'ውል',
#   'ነበረ',
#   'ኖቤሉ',
#   'መጣ'],
#  ['አንድነት',
#   'ፖርክ',
#   'ኰራ',
#   'እስደሳች',
#   'ኖረ',
#   'ደርግ',
#   'ዘመን',
#   'ተያያዘ',
#   'አዘነ',
#   'ስፍራ',
#   'ታሪክ',
#   'ግን',
#   'አየ',
#   'እውስ',
#   'ተገቢ',
#   'ሰአሊ',
#   'ግኝ*',
#   'በንደዚሁ',
#   'አሰበ',
#   'ተሰራ',
#   'ፊልም'],
#  ['ምግብ', 'ብርቱካን', 'እንጀራ', 'ጎን', 'አረ', 'ተወ', 'የመአድ', 'ስርአት', 'ተከበረ'],
#  ['ብዙ',
#   'እናውቅላችኇለን',
#   'ባይ',
#   'ጨፈለቀ',
#   'ሰደበ',
#   'ስራ',
#   'ሰራ',
#   'ሰደበ',
#   'ገረመ',
#   'ተሰራ',
#   'መልካም',
#   'በረታ',
#   'ደገፈ',
#   'አየ',
#   'አወቀ',
#   'አቃቂር',
#   'ውጥእ',
#   'ዶለተ',
#   'በዛ'],
#  ['ባህር',
#   'ዛፍ',
#   'ደገመ',
#   'ችግኝ',
#   'ነቀለ',
#   'ውሀ',
#   'ጠጣ',
#   'ተመካ',
#   'ገጨ',
#   'ሼር',
#   'እንዴ',
#   'ቆሎ',
#   'ቈረጠመ',
#   'ጥቅም',
#   'አነ',
#   'ማር',
#   'ወተት',
#   'ዝንጅብል',
#   'ጥር',
#   'ለውጥ',
#   'መጣ'],
#  ['ረባ',
#   'ጭቅጭቅ',
#   'ወደደ',
#   'ኪራይ',
#   'ሰብሳቢ',
#   'በረታ',
#   'ታገለ',
#   'ምድረካድሬ',
#   'ጨቀጨቀ',
#   'ቀላል',
#   'ተገለገለ',
#   'ናደ',
#   '"ትምክተኝነትና',
#   'ጠባብነት',
#   'ይስተዋልብኛል"',
#   'ብይ',
#   'ሁለቱንማ',
#   'ቻለ',
#   'ፈጠጠ'],
#  ['አሰበ', 'ሰካ', 'እውነት', 'እውቀት', 'በተመሰረትርው', 'ራእይ', 'ፓርቲ', 'ፋረ', 'ተከውረው', 'ኖረ'],
#  ['ጥቃት',
#   'ሞት',
#   'አወቀ',
#   'ኢራቅ',
#   'ሚሊሺያ',
#   'ኮማንደር',
#   'ነበረ',
#   'አቡ',
#   'ማህዲ',
#   'አል',
#   'ሙሀንዲስ',
#   'ተገኘ',
#   'ተባለ',
#   'ቃሲም',
#   'ሱሌማኒ',
#   'ከኢራን',
#   'ጠቀለለ',
#   'መሪ',
#   'አሊ',
#   'ሆመኒይ',
#   'ቀጠለ',
#   'ከፍተኛ',
#   'ባለስልጣን',
#   'ነበረ',
#   'አወቀ'],
#  ['ሀገር',
#   'ወገን',
#   'አንደለለዉ',
#   'ወጣት',
#   'ከፍተኛ',
#   'እንግልት',
#   'ሰቆቃ',
#   'እያሰቃየዉ',
#   'አሰከፊ',
#   'ሰርአት',
#   'መነሻዉ',
#   'ቅጥ',
#   'ያጣዉ',
#   'ኦሮሞ',
#   'የበለይነትና',
#   'የተረኝነት',
#   'ሰሜት',
#   'ግልጽ',
#   'መንግስት',
#   'መፍትሄ',
#   'ሊሰጠዉ',
#   'ዳተኛ'],
#  ['እንደምትጎርር', 'ገባ', 'ጌታ'],
#  ['ክልል',
#   'ክለብ',
#   'ጥንካሬ',
#   'ተቋቋመ',
#   'ሊግ',
#   'ቁንጮነት',
#   'መለሰ',
#   'ፈረሰኛ',
#   'ቡድን',
#   'ግንባታ',
#   'ሄደ',
#   'ቀደመ',
#   'ለየ',
#   'ተሻለ',
#   'አለባቸው',
#   'ወይስ',
#   'ችግር',
#   'ሂደት',
#   'በአፈጻጸሙ'],
#  ['አዲስ',
#   'ተቃዋሚ',
#   'ፓርቲ',
#   'ሳልሳይ',
#   'ወያነ',
#   'ትግራይ',
#   'ሳወት',
#   'ነገ',
#   'ጀመረ',
#   'ጠቀለለ',
#   'ጉባኤ',
#   'ያደርጋልሳወት',
#   'ጉባኤ',
#   'ፕሮግራም',
#   'ያጸድቃልአመራሮቹ',
#   'መረጠ',
#   'ተብሏልሳወት',
#   'የኢፌዲሪ',
#   'ህገመንግስት',
#   'ተሻሻለ',
#   'ጠየቀ',
#   'ፓርቲ'],
#  ['ኦነግ', 'ኦፌኮ', 'ኦብታ', 'ጥምረት', 'በረታ'],
#  ['ዛሬ', 'ልዩ', 'ቀን'],
#  ['ህወሀት', 'ሰነጠቀ', 'ግን', 'ሰነጠቀ', 'መታ', 'ይፋ', 'ጥያቄ'],
#  ['ግቢ', 'ደበደበ', 'ጠየቀ'],
#  ['ሀቅ', 'ተጫወተ', 'ሙዚቃ', 'አይጠገብ', 'እኮ'],
#  ['ኧረ', 'በግ', 'ወሬ', 'ቀላቀለ'],
#  ['"',
#   'ህጻን',
#   'ወለደ',
#   'ወንድ',
#   'ልጅ',
#   'ሰጠ',
#   'አለቅነት',
#   'ጫንቃ',
#   'ድንቅ',
#   'መካር',
#   'ሀያል',
#   'አምላክ',
#   'ዘላለም',
#   'አባት',
#   'ሰላም',
#   'አለቃ',
#   'ይጠራል"',
#   'ትንቢተ',
#   'ኢሳይያስ'],
#  ['አዲ_አበባ',
#   'ከተማ',
#   'ክልል',
#   'መንግስት',
#   'ክልል',
#   'ዉስጥ',
#   'ለየ',
#   'ባህል',
#   'የሚያስተዋዉቁበት',
#   'ባህል',
#   'ማህከል',
#   'ተቋቋመ',
#   'አዲስ_አበባ',
#   'አዲስ',
#   'አበቤዎችና',
#   'ከተማ'],
#  ['ምጽከባድ', 'ስህተት'],
#  ['ጦር', 'አብዛ', 'ፈለቀ', 'ቤመ', 'ተቀመጠ', 'አማራ', 'ማንበርከክ', 'ተቻለ'],
#  ['አማራ', 'ክልል', 'ሰላም', 'ደፈረሰ', 'ተጠረጠረ_ቁጥጥር', 'ስር_ዋሉ'],
#  ['ገና',
#   'አል',
#   'ከግዜ',
#   'በህላ',
#   'አብዛኛው',
#   'ተጠናወተ',
#   'የዘረኝነት',
#   'በሽታ',
#   'ወጣ',
#   'ድጋሚ',
#   'ተወልደ',
#   'ታላቅ',
#   'ነበረ',
#   'ሀገር',
#   'ዘመን',
#   'ታላቅ',
#   'ድርግ',
#   'ራስ',
#   'ቃል',
#   'የምነገባበትና',
#   'ራስ',
#   'አሻራ',
#   'ተቀመጠ',
#   'እንደያድርግልን',
#   'ምኞት'],
#  ['እግዚአብሄር', 'ከበረ', 'በላ', 'ከበረ', 'ከበረ'],
#  ['ኤፌሶን', 'ዳነ', 'ራስ', 'ቁር', 'ነፈሰ', 'ሰይፍ', 'ያዘ', 'እርስ', 'እግዚአብሄር', 'ቃል'],
#  ['አማርኛ', 'ልጅ', 'ክርስቲያን', 'ሙስሊም', 'አደገ'],
#  ['ኢሰፓ',
#   'ኢሰፓኮ',
#   'ወለደ',
#   'ነበረ',
#   'ፍንደቃ',
#   'አመሰራረት',
#   'ችግር',
#   'ጠፋ',
#   'ከነአካቴው',
#   'ጠፋ',
#   'ብልጽግና',
#   'ፓርቲ',
#   'ትምህርት',
#   'ቀሰመ',
#   'የኢሰፓ',
#   'ፓርቲ',
#   'አባል',
#   'ሰአት',
#   'የትነው'],
#  ['ፓትርያሪኩ', 'ሰለመስጂድ', 'ቃጠሎ', 'ተናገረ'],
#  ['አሜን'],
#  ['ሳላሀዲን', 'ሰኢድ', 'ፈረሰኛ', 'ተስፋ', 'ያዘ', 'መጣ'],
#  ['አብ',
#   'አለም',
#   'እታ',
#   'እንኮ',
#   'ብግዝያውን',
#   'ህዝቢ',
#   'ዘይመረጾን',
#   'መንግስቲ',
#   'አመት',
#   'መመላእታ',
#   'ዝተመርሀትን',
#   'መራ',
#   'ዘላን',
#   'ሀገር',
#   'ኤርትራ',
#   'ጥራይ',
#   'እያሃገርና',
#   'ብሰንኪ',
#   'ህግደፍ',
#   'አብነት',
#   'ስደት',
#   'ሞት',
#   'ማእሰርቲ',
#   'ኰላ',
#   'ትርከብ'],
#  ['የባዮሎጂ', 'ማረ', 'እሄንን', 'ሰማ', 'እራሳቸውን', 'አጠፈ'],
#  ['ፋሽን', 'ከፍታ', 'ወረደ', 'ልጅ', 'ፈለገ', 'ድምጽ', 'ወጣ', 'ተገደደ'],
#  ['ተሳሳተ', 'አሰበ', 'አቋም', 'ቀየረ', 'እየተሴረ'],
#  ['ዱንያ', 'ብላሽ', 'ተገኘ'],
#  ['የኮሌራ', 'ክትባት', 'ዘመቻ', 'ደቡብ'],
#  ['ደንበጫ', 'ፋርጣ', 'ተወዳደረ', 'መሰለ', 'እንዴ'],
#  ['ብልጽግና', 'ፖርቲ', 'አዲስ', 'ሹመኞች'],
#  ['ለየ',
#   'በግ',
#   'ፍየል',
#   'በር',
#   'ቆዳ',
#   'አይነት',
#   'ጣለ',
#   'ነበረ',
#   'ኤክስፖርት',
#   'ቀረጥ',
#   'ሙሉ',
#   'ተነሳ'],
#  ['እሄ',
#   'እኮ',
#   'ጻፈ',
#   'ለፋ',
#   'አስርት',
#   'አመት',
#   'ታሪክ',
#   'ትምህርት',
#   'ገነነ',
#   'ጥላቻ',
#   'ገባ',
#   'ሚያረግ',
#   'ጥላቻ',
#   'ተማረ',
#   'መጣ',
#   'ዛሬ',
#   'አመት',
#   'መጣ',
#   'ለዛ',
#   'ሃገሪቷ',
#   'ጥላቻ',
#   'አመሰ'],
#  ['ምርጫ', 'ውጤት', 'ሰርፕራይዝ', 'ጣመ'],
#  ['ኢራቅ',
#   'ተቃዋሚ',
#   'ባግዳድ',
#   'ተገኘ',
#   'አሜሪካ',
#   'ኤምባሲ',
#   'አካባቢ',
#   'መለሰ',
#   'ጀመረ',
#   'ኤምባሲ',
#   'ትናንት',
#   'ጥቃት',
#   'ደረሰ',
#   'አወቀ'],
#  ['ሰማይ',
#   'ምድር',
#   'ተቀበለ',
#   'መሪ',
#   'ተቀበለ',
#   'ያነተን',
#   'ጤናማ',
#   'ገረመ',
#   'አቢይ',
#   'ቀጠለ',
#   'እቃ',
#   'መጣ'],
#  ['ሰለቸ', 'ጣረ', 'ተከበረ', 'ጠቀለለ', 'ቀድሞ', 'ልእልና', 'ብልጽግና', 'ደረሰ'],
#  ['"ደሙን',
#   'አፈሰ',
#   'አጥንት',
#   'ከሰከሰ',
#   'ገነባ',
#   'ከብት',
#   'አየነዳ',
#   'ድንገት',
#   'አረፈ',
#   'ፈረሰ',
#   'ኩል',
#   'አይሰማውም"',
#   'ዳመነ',
#   'በላይነህ'],
#  ['ጌታቸው',
#   'አረጋዊ',
#   'ቃለመጠይቅ',
#   'ተከታትየዎለሁኝ',
#   'መንዳታ',
#   'ዳግማይ',
#   'ክብሮም',
#   'ግን',
#   'ሁቡእ',
#   'ድርታቹኮ',
#   'ዛር',
#   'አስራምናምን',
#   'አመትኮ',
#   'ምናቀው',
#   'አውሬ',
#   'ሁላ'],
#  ['ክልል',
#   'ግንኙነት',
#   'ረቂቅ_ዋጀ',
#   'ውይ*',
#   'ክልል',
#   'ወከለ',
#   'ተገኘ',
#   'ዘገባ',
#   'የኢትዮጵያፕሬስ',
#   'ኤጀንሲ',
#   'ታህሳስ',
#   'ቀን',
#   'አመመ'],
#  ['ፍልጥ', 'ሰበሰበ', 'አዲስ', 'አበቤ', 'ሰገጤ', 'አራዳ', 'ልጅ', 'ሙድ_ያዘ', 'ሞከረ'],
#  ['የሴናሪዮ',
#   'ቀረጻ',
#   'ስብሰባ',
#   'ግዜ',
#   'ውጤት',
#   'አላማ',
#   'ተጽእኖ',
#   'ፈጣሪ',
#   'ስብሰባ',
#   'ቀን',
#   'ሌሊት',
#   'ሴናሪዮዎች',
#   'ለየ',
#   'አመ'],
#  ['"ብልጽግና',
#   'ፓርቲ',
#   'እውነት',
#   'እውቀት',
#   'መሰረተ',
#   'ተሻገረ',
#   'አመነ',
#   'ድልድይ',
#   'ነው"',
#   'ጠማ',
#   'አብይ_አህመድ'],
#  ['ብልጽግና', 'ፓርቲ', 'ስራ_አስፈጻሚ', 'ኮሚቴ', 'ጀመረ', 'ስብሰባ', 'ድርግ'],
#  ['ይች',
#   'ልጅ',
#   'ሄደ',
#   'እምነት',
#   'አታቀውም',
#   'ብሄር',
#   'ማነቷን',
#   'አወቀ',
#   'እቃ',
#   'ሰውነት',
#   'ደጋግ',
#   'ለጋ',
#   'ቀላቀለ',
#   'የእራሷን',
#   'ማንነት',
#   'ግኝ*',
#   'ሰውነት',
#   'አለቀ'],
#  ['ሀገር',
#   'አእምሮ',
#   'ህመምተኛዉ',
#   'ነዉ',
#   'የተባለዉ',
#   'ተቀሽቧል',
#   'በተለይ',
#   'የፓለቲካ',
#   'ንቃተ',
#   'ህሌና',
#   'የምንለዉ',
#   'ሀገር',
#   'አበደ',
#   'ሁላችንም',
#   'አበደ',
#   'ረዳ',
#   'የሚፈዉሱን',
#   'አባት',
#   'በመሆናቸዉ',
#   'ሽማግሌ',
#   'መንግስት',
#   'መሰረተ'],
#  ['አማራ',
#   'ክልል',
#   'መንግስት',
#   'ገለጸ',
#   'ነፋ',
#   'ሰልፍ',
#   'ጠራ',
#   'እጅ',
#   'አነሳ',
#   'ትግል',
#   'ልመና',
#   'ዛሬ',
#   'አየ',
#   'ነገ',
#   'ጠፋ',
#   'ነፍስ',
#   'እባክህ',
#   'ፈራ',
#   'ፈራ'],
#  ['ታዲያ', '"ለምን', 'አገር', 'አልተበጠበጠም"', 'ቀየረ'],
#  ['ምርጫ', 'ትንበያ', 'ተመለከተ', 'ምርጫ_ቦርድ', '""', 'ጀመረ', 'መልካም', 'መሰለ'],
#  ['ለዝንኑ', 'ሺቲ', 'ድርያ', 'ጠማ', 'ደገመ', 'ሽርጥ', 'ያዘ', 'ሰሞን', 'እዛው'],
#  ['ገና',
#   'አል',
#   'ልዩ',
#   'በጎ_አድራጎት',
#   'አሁኑኑ',
#   'ተሳተፈ',
#   'ዛር',
#   'ለበጎነት',
#   'ረፈደ',
#   'የእግርኳስ',
#   'ጨዋታ',
#   'አረጋዊ',
#   'ቤት',
#   'ጥገና',
#   'ነጻ',
#   'ህክምና',
#   'ቁሳቁስ',
#   'ድጋፍ',
#   'ምሳ',
#   'ግብዛ',
#   'ተሳተፈ',
#   'ደወል'],
#  ['በደፈናው', 'ለማድበስበስ', 'ሞከረ', 'ግልጽ', 'አታብራራውምእስኪ', 'ችግር', 'በራ'],
#  ['ድምጸ', 'ወያነም', 'ህወሀትም', 'መረጃ', 'ጠራ', 'ሞከረ', '"የሀሰት', 'ተባለ', 'ነው"'],
#  ['ገንዘብ',
#   'ሰበሰበ',
#   'ዘመቻ',
#   'ጀመረ',
#   'ይቺ',
#   'ጽሁፍ',
#   'ማብራሪያ',
#   'ሰጠ',
#   'እምነት',
#   'እለታዊ_ኑሮ',
#   'ወጣ',
#   'ወረደ',
#   'ትምህርት',
#   'በብርግነትና',
#   'አካባቢ'],
#  ['ሞጣ',
#   'ጋይተው',
#   'ሙት',
#   'ሀብት_ንብረት',
#   'ጉዳይ',
#   'ምላሹ',
#   'ሰጠ',
#   'መጅሊሳችን',
#   'ጠየቀ',
#   'መንግስት',
#   'አካል',
#   'ሞጣ',
#   'ጉዳይ',
#   'ሰማ',
#   'ተናገረ',
#   'አየ'],
#  ['ፓስተሩ',
#   'ቶሎሳ',
#   'ተዋረደ',
#   'ጀዋር',
#   'ልክ',
#   'ገባ',
#   'አስደሳች',
#   'ምስራች',
#   'ዜና',
#   'ለእኢትዮጲያዊያን'],
#  ['“ለውጥ',
#   'ፈረሰ',
#   'አዲስ',
#   'ገነባ',
#   'አደገ',
#   'ፈለገ',
#   'በአል',
#   'ጨመረ',
#   'ተማረ',
#   'ሀይል',
#   'ያስፈልጋታል”',
#   'አረፈ',
#   'ነፍስ'],
#  ['ይሄ', 'አፍንጫ', 'የሚወጣውምልግልጉእእእጥፍጥኣዎ'],
#  ['አመት', 'እንዴ', 'ሳራ', 'ቲ'],
#  ['አራ',
#   'አሜርካ',
#   'አሳፋር',
#   'እርምጃ_ወሰደ',
#   'እየለች',
#   'ነዉ',
#   'አሜርካም',
#   'ጥቃት',
#   'ሰነዘረ',
#   'ምክንያት',
#   'ጥንቃቄ',
#   'ተደረገ',
#   'ዜጋ',
#   'ትዛዝ',
#   'ተላለፈ',
#   'ቢቢሲ',
#   'ይች',
#   'ምድር',
#   'ሰላም',
#   'አለም_ቀፈፈ',
#   'ቀነሰ',
#   'መጠጠ'],
#  ['አከከ',
#   'ፊሽ',
#   'ዘንድሮ',
#   'ማንቼ',
#   'ትንሽ',
#   'ቲም',
#   'ችግር',
#   'ለዛ',
#   'አርሴና',
#   'ተስፋ',
#   'ኖረ',
#   'መሰለ'],
#  ['ተቋረጠ',
#   'ማረ',
#   'ማረ',
#   'ሂደት',
#   'ቀጠለ',
#   'ለየ',
#   'አካላት',
#   'ውይ*',
#   'ድሬዳዋ',
#   'ዩኒቨርስቲ',
#   'አወቀ'],
#  ['ርጅ*', 'አወጋ', 'ሙስሊም', 'ያንን', 'ተግባራዊ', 'ድርግ', 'ጊዜ', 'ውጤታማ', 'ነበረ', 'ክፍል'],
#  ['ነገ', 'ዋዜማ', 'ቀን', 'ኦቨራይድ', 'ይደረጋልዛሬ', 'ዋዜማ'],
#  ['አማራ', 'ለፒፒ', 'ለኢዜማ', 'አብይ', 'ደገፈ', 'ለቅሶ', 'ደስታ'],
#  ['እስክንድር',
#   'ገባ',
#   'ቃል',
#   'በቄሮዎች',
#   'እጅ',
#   'ጡት_ቈረጠ',
#   'አማራ',
#   'የአኖሌ',
#   'ሀውልት',
#   'ጎንደር',
#   'ከተማ',
#   'ገነባ',
#   'ዝግጅት',
#   'ጥንቅቅ'],
#  ['አመት',
#   'ቈጠረ',
#   'ግብርና',
#   'ህይወት',
#   'ተንጠለጠለ',
#   'አረሰ',
#   'ዶማ',
#   'በር',
#   'ፍጥነት',
#   'አርሶያውም',
#   'አመት',
#   'ጊዜ',
#   'መራ',
#   'ከተማ_ነዋሪ',
#   'በንሮ',
#   'ውድነት',
#   'ከለበ',
#   'ብራንድ',
#   'የለላትን',
#   'ሀገር',
#   'ምጸት'],
#  ['ያእቆብ',
#   'ድንኳን',
#   'እግዚአብሄር',
#   'ጽዮን',
#   'ደጅ',
#   'ወደደ',
#   'እግዚአብሄር',
#   'ከተማ',
#   'ሆይ',
#   'የተከበር',
#   'በላ',
#   'ጽዮን_ማርያ',
#   'ሀገር',
#   'ፍጹም',
#   'ሰላም',
#   'ፍቅር',
#   'በዛ'],
#  ['እርዳታ',
#   'ጥሪመደገፍ',
#   'ሻ',
#   'በፖለቲካል',
#   'አለም_ቀፈፈ',
#   'ግንኙነት',
#   'ማስተር',
#   'ዲግሪ',
#   'ጋዜጠኛ',
#   'ሺ',
#   'ዳቢ',
#   'ሺ',
#   'ቈጠረ',
#   'ሆሊውድ',
#   'ሰራ',
#   'ፊልም',
#   'አማርኛ',
#   'ተረጐመ'],
#  ['የኢትዮጵያስፖርትፌዴሬሽን', 'አየ', 'ገባ', 'አመት', 'ምርጥ', 'ትርኢት'],
#  ['ለማ_መገርሳ',
#   'ደመረ',
#   'አልተደመረ',
#   'ብልጽግና',
#   'ፓርቲ',
#   'ውን',
#   'አልሆነ',
#   'አብይ',
#   'ለማ',
#   'ጣለ',
#   'ኦዲፒ',
#   'ከፈለ',
#   'አልተከፈለች',
#   'ራስ',
#   'ጉዳይ',
#   'ሳበ',
#   'ችግር'],
#  ['ይሄ', 'ሽማግሌ', 'ግን', 'በቃ', 'ንስሀ', 'ገባ'],
#  ['አዲስ', 'ሹም', 'ቀና', 'ሰጠ', 'በማእራቡ', 'አለም', 'ለመደ', 'ሰራ'],
#  ['መሪ',
#   'ህልማቸዉን',
#   'ልብ',
#   'ገራ',
#   'ያንን',
#   'እዉን',
#   'ድርግ',
#   'ደመረ',
#   'ህልም',
#   'ችግር',
#   'ሲኖርያንን',
#   'ችግር',
#   'ተናገረ',
#   'መራ',
#   'ውይ*',
#   'ተከራከረ',
#   'ኋላ',
#   'ማይል',
#   'ተከታይ',
#   'ነዉ',
#   'የሚያስፈልጋቸዉ',
#   'ደመረ'],
#  ['ይኼካላስቆጨን',
#   'አፈረ',
#   'ንትርክ',
#   'ውዝግብ',
#   'እርግፍ',
#   'አረገ',
#   'ተወ',
#   'ድህነት',
#   'መተን',
#   'ልመና',
#   'ምጽዋት',
#   'ድል',
#   'ነሳ',
#   'ራስ',
#   'አለፈ',
#   'ምንተርፍ',
#   'ተጋ',
#   'መረጠ',
#   'ውርደት',
#   'ልመና',
#   'ኖረ',
#   'የበታችነትን',
#   'ችሮታ',
#   'ጠበቀ',
#   'ደጀጠኚነትን'],
#  ['ቦታ',
#   'ጠየቀ',
#   'ካሳ_ከፈለ',
#   'ኢንቨስትመነት',
#   'ጠየቀ',
#   'መሪቱን',
#   'መንግስት',
#   'ካሳ',
#   'ሂሳብ',
#   'ከፈለ',
#   'መሪት',
#   'ያዘ',
#   'ራስ',
#   'ትርፍ',
#   'ስለሚችልአንደኛ',
#   'ኢንቨስትመንት',
#   'ቅድሚያ',
#   'ተፈላገነት',
#   'ከአዋጭነት',
#   'ፈተሸ',
#   'አለፈ',
#   'ፈቀደ',
#   'የሳታሚወች',
#   'መጸሀፍ',
#   'አተመ',
#   'ገባ'],
#  ['ለየ',
#   'ሀገር',
#   'ክልል',
#   'አዲስ_አበባ',
#   'ስራ',
#   'ኖረ',
#   'ቤት',
#   'ድል',
#   'ተጠቃሚ',
#   'እርካታ',
#   'ከተማ_ነዋሪ',
#   'ተቃራኒ',
#   'ግጥም'],
#  ['ተነሳ', 'ወንድም', 'ጠራ', 'ሴት', 'ጀግና', 'ጀግና', 'ያቺ', 'ልበ', 'ብርት'],
#  ['ታምራት_ነገራ', 'አብይ', 'ኩል', 'ኤርትራዊ', 'አወቀ'],
#  ['ፈጀ', 'ደበነ', 'ፓስፓርት', 'መሰረታዊ', 'ተገለገለ', 'ሳለየመንቀሳቀስ', 'ሰራ', 'መብት', 'ገደበ'],
#  ['ቀን', 'ተቈጣ', 'ዝም', 'ማይል'],
#  ['ዛሬ', 'ቀማ', 'እንቅልፍ', 'ኪኒን', 'ነገ', 'ነቃ', 'አስቤአለሁ'],
#  ['ይጠቀማሉድሃው',
#   'እርስ',
#   'ቈሰለ',
#   'ገደለ',
#   'ፖለቲካ',
#   'ኢኮኖሚ',
#   'ሀይል',
#   'ተደለደለ',
#   'እንቅርት',
#   'ጆሮ',
#   'ደግፍ',
#   'ሀገር',
#   'በቀል',
#   'ድንቄ'],
#  ['ጥር',
#   'ጥር',
#   'ስር',
#   'መልካም',
#   'መልካም',
#   'ሳበ',
#   'እዉነት',
#   'እዉነቱን',
#   'ተናገረ',
#   'ዉጤታችሁ',
#   'አማረ'],
#  ['ጥር',
#   'ዜና',
#   'ግን',
#   'ድርሻ',
#   'አካላት',
#   'ካላቹ',
#   'በመሰርተ',
#   'ልማት',
#   'ከፍተኛ',
#   'ተደራሽነት',
#   'አካታችነት',
#   'አጣ',
#   'አቀደ',
#   'ገመገመ',
#   'አሳብ',
#   'መጨምር',
#   'ችግር',
#   'ጋራ',
#   'ለመፋትሂ',
#   'ፈለገ',
#   'አካል',
#   'ጉዳተኛ',
#   'ሰረረ'],
#  ['ክቡር_ጠማ',
#   'ዶር_አብይ_አህመድ',
#   'በቅድማያ',
#   'የከበራ',
#   'ሰላምታ',
#   'ላቀርብሎት',
#   'ፈልጋለሁ',
#   'ቀጠለ',
#   'ራስ',
#   'አወቀ',
#   'ለስታዉቅ',
#   'ሀዋሳ',
#   'ዩንቨርሲቲ',
#   'ሁለተኛ',
#   'ማስተር',
#   'ተማሪ',
#   'ቀጠለ',
#   'ፈለገ',
#   'መረጃ',
#   'ሰጠ'],
#  ['አመነ', 'ከባቢ', 'ኖረ', 'ትክክል', 'ቢኒ', 'አጠቃላይ', 'ግን', 'ተነጻጸረ', 'ብይ', 'አሰበ'],
#  ['"ከዋሻ',
#   'ወጣ',
#   'ሌሊት',
#   'ወፍ',
#   'ትሆናለች"',
#   '"ወደ',
#   'ግራ',
#   'ትበራላች"',
#   'አለዛሬ',
#   'ባህርዳር',
#   'አማራ',
#   'ጣለ',
#   'መከራ',
#   'አየ',
#   'ባንዲራ',
#   'ሰልፍ',
#   'ያዘ',
#   'ወጣ',
#   'ነገ',
#   'መጣ',
#   'ገመተ',
#   'ቀላል'],
#  ['ሀገር', 'እድገት', 'ግንባታ', 'ዘርፍ', 'ሚና', 'አደገ', 'መንግስት', 'ድጋፍ', 'ጠማ', 'አቢይ'],
#  ['ማቴዎስ', 'ወንጌል', '"ጌታችሁ', 'ሰአት', 'መጣ', 'አወቀ', 'እንግዲህ', 'ንቁ"'],
#  ['ሀይማኖት',
#   'ሽፋን',
#   'ተወራ',
#   'ለም',
#   'ቀጥተኛ',
#   'ጥያቄ',
#   'ጠየቀ',
#   'ጀመረ',
#   'እምነት',
#   'አካባቢ',
#   'አማራ',
#   'ከፈለ',
#   'ሰራ',
#   'ከኦነግና',
#   'ትህንግ',
#   'የሻብእያ',
#   'ተላላኪ',
#   'ብርሀን_ነጋ',
#   'አንዳርጋቸው',
#   'ጽጌ',
#   'ድርጅት',
#   'ኢዜማ',
#   'ይሄ',
#   'ግልጽ'],
#  ['ዋነኛ', 'አንገብጋቢ', 'ጥያቄ', 'ግንቦት', 'ሃያ', 'ተከበረ', 'ወይስ', 'ተከበረ'],
#  ['በረቀ',
#   'ሀገር',
#   'እንጅ',
#   'ግለሰብ',
#   'ተከተለ',
#   'ሀገር',
#   'እጅ',
#   'ሀገር',
#   'አገዘ',
#   'ከበረ',
#   'አደገ',
#   'አደገ',
#   'የሚያደናቅፈንም',
#   'ቀላል',
#   'ተግሳጽ',
#   'ተሸነፈ'],
#  ['ይሄ',
#   'ሴት',
#   'ከበረ',
#   'ጉዳይ',
#   'ፍጹም',
#   'ተገኛኘ',
#   'ሙያጋር',
#   'ተዋወቀ',
#   'በለጠ',
#   'ረዳ',
#   'ኳስ',
#   'ያለአግባብና',
#   'ጥናት',
#   'ባከነ',
#   'ግብር',
#   'ከፈለ',
#   'ገንዘብ',
#   'ሳበ',
#   'ገባ',
#   'ንግር',
#   'ጠቀመ'],
#  ['"',
#   'አዳነ',
#   'ቅዱስ',
#   'ጠራ',
#   'ጠራ',
#   'እግዚአብሄር',
#   'አሳብ',
#   'ጸጋ',
#   'መጠን',
#   'ስር',
#   'መጠን',
#   'ጸጋ',
#   'ዘላለም',
#   'ዘመን',
#   'ፊት',
#   'ክርስቶስ',
#   'ኢየሱስ',
#   'ተሰጠን"ኛ',
#   'ጢሞ'],
#  ['እስክንድር', 'ጽንፈኛ', 'አማራ', 'መረጠ'],
#  ['አየ', 'ግምገማ', 'ተገኛኘ', 'የማይክሮ', 'ቅድሚያ', 'ጠቀመ', 'ቅድሚያ', 'አዲስ', 'የሚሰጡዋቸውን'],
#  ['አብይ',
#   'መንግስት',
#   'ከነ',
#   'ኮቶቱ',
#   'አመት',
#   'ገደማ',
#   'ተሸከመ',
#   'ግል',
#   'እሄ',
#   'ኮቶቱን',
#   'እርግፍ',
#   'አርገ',
#   'እራሴን',
#   'አጸዳለው'],
#  ['እርስ', 'ቀላል', 'ምግብ', 'ለም'],
#  ['ትክክል', 'ትክክል', 'ውነታ', 'ረዳ', 'ቦታ', 'እራስን', 'አስቀመጠ'],
#  ['ከእንግዲህ', 'ተከተለ', 'ተሸናፊ', 'ቀጥታ', 'ሲኦል', 'ላከ'],
#  ['ናደ', 'አረገ', 'ሀገር', 'እደለኛ', 'የገባቸዉ', 'ደነቀ'],
#  ['ቤተሰብ',
#   'ስጥ',
#   'አደለ',
#   'ጥር',
#   'ሰራ',
#   'ስተት',
#   'አየ',
#   'ቱን',
#   'ጥር',
#   'ተወ',
#   'ቱን',
#   'ስተት',
#   'ምንተቸው',
#   'ፈጠረ',
#   'ልፋት',
#   'ሰጠ',
#   'በርታ',
#   'ጐን'],
#  ['አብ',
#   'አለም',
#   'ከም',
#   'ናይ',
#   'ኤርትራ',
#   'መከራ',
#   'ብስራአት',
#   'ህግደፍ',
#   'ኣይተራኣየን',
#   'ምኽንያቱ',
#   'መንግስትቲ',
#   'ንህዝቡ',
#   'ኢሉ',
#   'ነበረ',
#   'መንግስቲ',
#   'ንህዝቡ',
#   'የገልጊል',
#   'ኣብዚ',
#   'ግን',
#   'መወዳእታ',
#   'ዘይብሉ',
#   'ህዝቢ',
#   'ባርያ',
#   'ኮይኑ',
#   'ነበረ',
#   'ኣሎ',
#   'ህግደፍ',
#   'መጸይቲ',
#   'ደም'],
#  ['የኢዜማን',
#   'ቴሌግራም_ቻናል',
#   'ተከተለ',
#   'ፖሊሲ',
#   'ደንብ',
#   'ተዘጋጀ',
#   'እውቀት',
#   'መሰረተ',
#   'የሃገሪቷ',
#   'ችግር',
#   'ስሜት',
#   'ነዳ',
#   'ፈታ',
#   'ገባ',
#   'አየ',
#   'ሞከረ',
#   'አማራጭ'],
#  ['አቤት', 'ውሸት'],
#  ['መሰለ', 'ጠፋ', 'ዘባራቂ', 'መርዝ'],
#  ['ታሪክ',
#   'አለፈ',
#   'መረጠ',
#   'እውስ',
#   'ለመጭው',
#   'ትውልድ',
#   'ማንነት',
#   'ተላለፈ',
#   'ጦርነት',
#   'መረጠ',
#   'ታሪክ',
#   'ጻፈ',
#   'ጻፈ',
#   'ታሪክ',
#   'ጦር_መሳሪያ',
#   'ጠቀመ',
#   'ዛር'],
#  ['መኪና_አደጋ', 'ይሰመርበት', 'ወጣ', 'ቀረ'],
#  ['እግዚአብሄር', '“ልጄ', 'ሆይ', 'ልብ', 'ሰጠ', 'ምሳሌ'],
#  ['ለማ', 'ለማ', 'አረም', 'መሰለ', 'ዘፈነ', 'ደህና', 'ደህና'],
#  ['ሂደት', 'ተስፋው', 'በአንጻራዊነት', 'ገለልተኛ', 'ምርጫ_ቦርድ', 'መሰለ'],
#  ['ግቢ',
#   '"',
#   'ኦፕን',
#   'ኮሌጂ"',
#   'አሊ',
#   'ቢራ',
#   '"ሲንደሬላ',
#   'ምቾቱ"',
#   'ሙሉብርሀን',
#   'አወቀ',
#   'ዘፈን',
#   'ጥልእ',
#   'አረቀ',
#   'ኦሮማራ',
#   'ጓደኛ',
#   'ግን',
#   'ደህና'],
#  ['ኢህአዴግ', 'ጠፋ', 'ብልጽግና', 'ክብር', 'ሰጠ', 'ድርግ', 'ብልጽግና'],
#  ...]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
def create_gensim_lsa_model(doc_clean,number_of_topics,words):
    """
    Input  : clean document, number of topics and number of words associated with each topic
    Purpose: create LSA model using gensim
    Output : return LSA model
    """
    #dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    # generate LSA model
    lsamodel = LsiModel(bow_corpus, num_topics=number_of_topics, id2word = dictionary)  # train model
    print(lsamodel.print_topics(num_topics=number_of_topics, num_words=words))
    return lsamodel

# %%
# LSA Model
number_of_topics=7
words=10
#document_list,titles=load_data("","articles.txt")
#clean_text=preprocess_data(document_list)
model=create_gensim_lsa_model(bow_corpus,number_of_topics,words)
# Out:
# [(0, '-0.268*"ድርግ" + -0.229*"ሀገር" + -0.201*"አየ" + -0.199*"ገባ" + -0.199*"ኖረ" + -0.182*"ግን" + -0.178*"አማራ" + -0.168*"አወቀ" + -0.158*"ሰጠ" + -0.154*"መንግስት"'), (1, '0.725*"አማራ" + 0.431*"ክልል" + -0.313*"ድርግ" + -0.173*"ሀገር" + -0.141*"አየ" + 0.112*"ኖረ" + 0.100*"ሙስሊም" + 0.100*"መንግስት" + -0.096*"ሰላም" + 0.082*"ኦሮሞ"'), (2, '-0.814*"ድርግ" + 0.387*"ሀገር" + -0.203*"አማራ" + 0.190*"ኖረ" + 0.116*"ሰላም" + 0.079*"አወቀ" + 0.074*"አመት" + -0.072*"ክልል" + 0.070*"ፓርቲ" + 0.067*"ግን"'), (3, '-0.674*"ሀገር" + 0.406*"አየ" + 0.306*"ግን" + -0.259*"ድርግ" + -0.177*"ሰላም" + 0.129*"ሰጠ" + -0.125*"አማራ" + 0.117*"አወቀ" + 0.116*"ፓርቲ" + -0.086*"ኖረ"'), (4, '0.593*"አየ" + -0.533*"ኖረ" + -0.316*"አወቀ" + -0.239*"ግን" + 0.202*"ሀገር" + 0.154*"ገባ" + 0.143*"ሰጠ" + 0.133*"አማራ" + 0.104*"ሰላም" + -0.103*"ፓርቲ"'), (5, '-0.466*"ገባ" + 0.460*"ኖረ" + 0.443*"አየ" + -0.368*"ፓርቲ" + -0.193*"ብልጽግና" + -0.155*"መንግስት" + -0.139*"ጀመረ" + 0.127*"ሀገር" + -0.092*"ምርጫ" + -0.090*"ያዘ"'), (6, '-0.629*"አወቀ" + 0.473*"ገባ" + 0.377*"ግን" + 0.307*"ኖረ" + -0.135*"ተገኘ" + -0.109*"ደረሰ" + -0.106*"ሰጠ" + -0.086*"አማራ" + -0.085*"ሰላም" + -0.081*"አመት"')]

# %%
text_data=[]
for x in processed_docs:
    str_docs=' '.join(x)
    text_data.append(str_docs)

# %% [markdown]
# text_data

# %%
def compute_coherence_values(dictionary, doc_term_matrix, start, stop, step):
    """
    Input   : dictionary : Gensim dictionary
              corpus : Gensim corpus
              texts : List of input texts
              stop : Max num of topics
    purpose : Compute c_v coherence for various number of topics
    Output  : model_list : List of LSA topic models
              coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, stop, step):
        # generate LSA model
        model = LsiModel(bow_corpus, num_topics, id2word = dictionary)  # train model
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=processed_docs, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return coherence_values
    #return model_list, coherence_values

# %%
def plot_graph(doc_clean,start, stop, step):
    coherence_values = compute_coherence_values(dictionary, bow_corpus, start,stop, step)
    # Show graph
    x = range(start, stop, step)
    plt.plot(x, coherence_values)
    plt.xlabel("Number of Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()

start,stop,step=2,12,1
plot_graph(bow_corpus,start,stop,step)
